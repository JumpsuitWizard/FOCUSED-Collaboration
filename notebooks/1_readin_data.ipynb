# %% [markdown]
# ## FOCUSED
# - Author:  Reshama Shaikh
#
# ## Data Sources
# 1. S&P 500
# 1. OSCI Index
# 1. Suzy spreadsheet
# 1. OSPO Landscape (Todo group)

# %% [markdown]
# ---

# %% [markdown]
# ## Date

# %%
from datetime import date

current_date = date.today()
print("Today's date:", current_date)
# Out:
# Today's date: 2022-05-21

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd 
import numpy as np
import requests
import time
import csv
from pprint import pprint

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
# %load_ext watermark
# %watermark -n -v -m -g -iv
# Out:
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.25.0
#
# Compiler    : Clang 11.1.0
# OS          : Darwin
# Release     : 19.6.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 4
# Architecture: 64bit
#
# Git hash: 4b28b648a682462bee305c284f3bdd5d5d41c43a
#
# csv     : 1.0
# plotly  : 5.4.0
# numpy   : 1.20.2
# requests: 2.25.1
# pandas  : 1.3.3

# %% [markdown]
# ## Set pandas view options

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 1. Data Source:  S&P 500

# %%
datapath="data_raw/"

def get_raw_data(data_url, file_name):
    file_url = data_url + "/" + file_name
    # !wget -N {file_url} -P {datapath} 
    
def read_raw_data(file_name):
    df_use = pd.read_csv(datapath+file_name)
    
    return df_use

# %%
data_url='https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/'
file_name = 'constituents.csv'

#run once
#get_raw_data(data_url, file_name)

# %%
# run once
#!mv data_raw/constituents.csv data_raw/sp500.csv

# %%
file_name='sp500.csv'
df_sp = read_raw_data(file_name)

print(df_sp.shape)
df_sp.head(5)
# Out:
# (505, 3)
#   Symbol                 Name       Sector
# 0    MMM                   3M  Industrials
# 1    AOS          A. O. Smith  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV               AbbVie  Health Care
# 4   ABMD              Abiomed  Health Care

# %% [markdown]
# ### 2. Data Source:  OSCI

# %%
data_url='https://ststaticprodosciwebz2vmu.blob.core.windows.net/data/osci-ranking/daily'
file_name = '2022-04-17.json'

#run once
#get_raw_data(data_url, file_name)

# %%
# run once
#!mv data_raw/2022-04-17.json data_raw/osci.json

# %%
file_name='osci.json'
file_name
# Out:
# 'osci.json'

# %%
import json
 
# Opening JSON file
f = open('data_raw/osci.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)

print(len(data))
#print(data)


# Iterating through the json
# list
for i in data['date'][0]:
    print(i)
 
# Closing file
f.close()
# Out:
# 3
# 2

# %%
print(data['date'])
print(type(data))
print(type(data['date']))
#print(data['date'].['comparedDate'])
#print(data['date'][0]['data'])
print(data['date'], data['data'][0]['company'])
# Out:
# 2022-04-17
# <class 'dict'>
# <class 'str'>
# 2022-04-17 Google

# %%
#pd.read_json('data_raw/osci.json')

# %%
# Normalizing data
multiple_level_data = pd.json_normalize(data, record_path =['data'])
#, meta =['original_number_of_clusters','Scaler','family_min_samples_percentage'], 
#meta_prefix='config_params_', record_prefix='dbscan_')

# Saving to CSV format
#multiple_level_data.to_csv('multiplelevel_normalized_data.csv', index=False)

multiple_level_data.head(1)
# Out:
#    positionChange company  activeContributors  activeContributorsChange  \
# 0             0.0  Google              4017.0                     273.0
#
#    totalCommunity  totalCommunityChange  position  \
# 0            8676                 431.0         1
#
#                                                  yoy  \
# 0  [{'date': '2020-04-17', 'active': 2587.0}, {'d...
#
#                                         contributors  \
# 0  [{'Contributor': 'Modular Magician', 'Commits'...
#
#                                            languages  \
# 0  [{'name': 'Brightscript', 'amount': 5}, {'name...
#
#                                             licenses    industry
# 0  [{'name': 'apache-2.0', 'amount': 180027}, {'n...  Technology

# %%
keep_cols = ['positionChange', 'company', 'activeContributors', 'activeContributorsChange', 
             'totalCommunity', 'totalCommunityChange', 'position', 'industry'
            ]

df_osci = multiple_level_data.filter(keep_cols)
df_osci['in_osci']=1

print(df_osci.shape)
df_osci.head(5)
# Out:
# (298, 9)
#    positionChange    company  activeContributors  activeContributorsChange  \
# 0             0.0     Google              4017.0                     273.0
# 1             0.0  Microsoft              3630.0                     308.0
# 2             0.0    Red Hat              2965.0                     159.0
# 3             0.0      Intel              1557.0                     112.0
# 4             0.0        IBM              1419.0                     128.0
#
#    totalCommunity  totalCommunityChange  position    industry  in_osci
# 0            8676                 431.0         1  Technology        1
# 1            8128                 545.0         2  Technology        1
# 2            4594                 188.0         3  Technology        1
# 3            3504                 190.0         4  Technology        1
# 4            3515                 259.0         5  Technology        1

# %%
df_sp = df_sp.rename(columns=
                         {'Name': 'company'
                             })
print(df_sp.shape)
df_sp['in_sp500']=1
df_sp.head(5)
# Out:
# (505, 3)
#   Symbol              company       Sector  in_sp500
# 0    MMM                   3M  Industrials         1
# 1    AOS          A. O. Smith  Industrials         1
# 2    ABT  Abbott Laboratories  Health Care         1
# 3   ABBV               AbbVie  Health Care         1
# 4   ABMD              Abiomed  Health Care         1

# %%
print(len(df_osci['company'].unique()))
print(len(df_sp['company'].unique()))
# Out:
# 298
# 505

# %%
df_parta = df_sp.merge(df_osci, left_on="company", right_on="company", how="outer")
print(len(df_parta))
df_parta.head()
# Out:
# 781
#   Symbol              company       Sector  in_sp500  positionChange  \
# 0    MMM                   3M  Industrials       1.0             NaN
# 1    AOS          A. O. Smith  Industrials       1.0             NaN
# 2    ABT  Abbott Laboratories  Health Care       1.0             NaN
# 3   ABBV               AbbVie  Health Care       1.0             NaN
# 4   ABMD              Abiomed  Health Care       1.0             NaN
#
#    activeContributors  activeContributorsChange  totalCommunity  \
# 0                 NaN                       NaN             NaN
# 1                 NaN                       NaN             NaN
# 2                 NaN                       NaN             NaN
# 3                 NaN                       NaN             NaN
# 4                 NaN                       NaN             NaN
#
#    totalCommunityChange  position industry  in_osci
# 0                   NaN       NaN      NaN      NaN
# 1                   NaN       NaN      NaN      NaN
# 2                   NaN       NaN      NaN      NaN
# 3                   NaN       NaN      NaN      NaN
# 4                   NaN       NaN      NaN      NaN

# %%
print(len(df_parta['company'].unique()))
# Out:
# 781

# %%
df_parta = df_parta.rename(columns=
                         {'Symbol': 'symbol',
                          'Sector': 'sector',
                          'position': 'osci_position'
                             })

new_order = ['symbol', 'company','sector', 'industry',
             'in_sp500','in_osci', 'osci_position'
            ]

df_parta = df_parta.reindex(new_order, axis=1)

# %%
df_parta.head()
# Out:
#   symbol              company       sector industry  in_sp500  in_osci  \
# 0    MMM                   3M  Industrials      NaN       1.0      NaN
# 1    AOS          A. O. Smith  Industrials      NaN       1.0      NaN
# 2    ABT  Abbott Laboratories  Health Care      NaN       1.0      NaN
# 3   ABBV               AbbVie  Health Care      NaN       1.0      NaN
# 4   ABMD              Abiomed  Health Care      NaN       1.0      NaN
#
#    osci_position
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df_check = df_parta.groupby(['in_sp500','in_osci']).count()
df_check
# Out:
#                   symbol  company  sector  industry  osci_position
# in_sp500 in_osci
# 1.0      1.0          22       22      22        22             22

# %%
df_check = df_parta.groupby(['in_sp500']).count()
df_check
# Out:
#           symbol  company  sector  industry  in_osci  osci_position
# in_sp500
# 1.0          505      505     505        22       22             22

# %%
df_check = df_parta.groupby(['in_osci']).count()
df_check
# Out:
#          symbol  company  sector  industry  in_sp500  osci_position
# in_osci
# 1.0          22      298      22       298        22            298

# %%
df_check = df_parta['company'].count() 
df_check
# Out:
# 781

# %%
#df_parta.head(5)

# %%
#df_parta.dtypes

# %%
#df_sample = df_parta.sample(20)

# %%
#df_sample.sort_values(by=['company'])

# %%
df_parta[df_parta['company']=="Google"]
# Out:
#     symbol company sector    industry  in_sp500  in_osci  osci_position
# 505    NaN  Google    NaN  Technology       NaN      1.0            1.0

# %%
df_sorted = df_parta.sort_values(by=['company'])
df_sorted.head(5)
# Out:
#     symbol      company            sector    industry  in_sp500  in_osci  \
# 0      MMM           3M       Industrials         NaN       1.0      NaN
# 767    NaN    4teamwork               NaN  Technology       NaN      1.0
# 758    NaN       5minds               NaN  Technology       NaN      1.0
# 1      AOS  A. O. Smith       Industrials         NaN       1.0      NaN
# 7      ADM          ADM  Consumer Staples         NaN       1.0      NaN
#
#      osci_position
# 0              NaN
# 767          285.0
# 758          276.0
# 1              NaN
# 7              NaN

# %%
df_sample = df_sorted.sample(10)
df_sample
# Out:
#     symbol                    company                  sector    industry  \
# 727    NaN                Loodos Tech                     NaN  Technology
# 357     PH            Parker-Hannifin             Industrials         NaN
# 306    MCK       McKesson Corporation             Health Care         NaN
# 554    NaN                  Collabora                     NaN  Technology
# 249    ICE  Intercontinental Exchange              Financials         NaN
# 241    IEX           IDEX Corporation             Industrials         NaN
# 315    MAA     Mid-America Apartments             Real Estate         NaN
# 313     MU          Micron Technology  Information Technology         NaN
# 548    NaN                        WIX                     NaN  Technology
# 620    NaN                       HERE                     NaN  Technology
#
#      in_sp500  in_osci  osci_position
# 727       NaN      1.0          244.0
# 357       1.0      NaN            NaN
# 306       1.0      NaN            NaN
# 554       NaN      1.0           62.0
# 249       1.0      NaN            NaN
# 241       1.0      NaN            NaN
# 315       1.0      NaN            NaN
# 313       1.0      NaN            NaN
# 548       NaN      1.0           56.0
# 620       NaN      1.0          137.0

# %% [markdown]
# ### 3. Data Source:  Suzy spreadsheet

# %%
file_name = 'classification_suzy.csv'

df_suzy = pd.read_csv('data_raw/'+file_name)
df_suzy['in_suzy']=1

df_suzy = df_suzy.rename(columns=
                         {'Company': 'company',
                          'Level of Engagement': 'os_engagement',
                          'TODO Member': 'todo_member',
                          'TODO Adopter': 'todo_adopter',
                          'Main Business': 'area',
                          'Relevance to Core Business': 'relevance'
                             })

df_suzy.head(3)
# Out:
#     company date_updated_suzy  \
# 0      AT&T        2021-05-07
# 1      SAIC        2021-05-07
# 2  Vapor IO        2021-05-07
#
#                                       Main Business  Area of Business Value  \
# 0  Telcom/operator is main revenue source (also m...               software
# 1  SAIC integrates multiple disciplines to provid...               services
# 2                               edge computing infra               software
#
#     relevance os_engagement todo_member todo_adopter  \
# 0  Accelerant    Co-Leading         NaN          NaN
# 1  Accelerant     Combining         NaN          NaN
# 2  Accelerant    Co-Leading         NaN          NaN
#
#   Linux Foundation (Platinum + Gold)  \
# 0                                  X
# 1                                NaN
# 2                                NaN
#
#   GitHub list https://github.com/collections/open-source-organizations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   OSCI Index top 60(as of Feb 2021)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#                                            Reasoning  \
# 0  I sense that AT&T sees investments as strategi...
# 1  SAIC gov't focused. They contribute (e.g. RedH...
# 2  Using os for trust, function, ecosystem develo...
#
#                         GitHub Note Response to survey  \
# 0                          NaN  NaN                NaN
# 1  https://github.com/saic-oss  NaN                NaN
# 2                          NaN  NaN                NaN
#
#   Survey: What do you consider to be your company's dominant open source investment where there are likely shared dependencies?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Survey: Want to hear more?  Emailed to:  in_suzy
# 0                         NaN         NaN        1
# 1                         NaN         NaN        1
# 2                         NaN         NaN        1

# %%
keep_cols = ['company', 'area','os_engagement', 'in_suzy', 'relevance' 
            ]
            #'activeContributors', 'activeContributorsChange', 
            # 'totalCommunity', 'totalCommunityChange', 'position', 'industry'
            #]

df_suzy = df_suzy.filter(keep_cols)

print(df_suzy.shape)
df_suzy.head(3)
# Out:
# (141, 4)
#     company os_engagement  in_suzy   relevance
# 0      AT&T    Co-Leading        1  Accelerant
# 1      SAIC     Combining        1  Accelerant
# 2  Vapor IO    Co-Leading        1  Accelerant

# %%
print(len(df_suzy['company'].unique()))
# Out:
# 141

# %%
df_check = df_suzy.groupby(['in_suzy']).count()
df_check
# Out:
#          company  os_engagement  relevance
# in_suzy
# 1            141             55         55

# %%
df_partb = df_sorted.merge(df_suzy, left_on="company", right_on="company", how="outer")
df_partb['company_count']=1
print(df_partb.shape)
df_partb.head()
# Out:
# (876, 11)
#   symbol      company            sector    industry  in_sp500  in_osci  \
# 0    MMM           3M       Industrials         NaN       1.0      NaN
# 1    NaN    4teamwork               NaN  Technology       NaN      1.0
# 2    NaN       5minds               NaN  Technology       NaN      1.0
# 3    AOS  A. O. Smith       Industrials         NaN       1.0      NaN
# 4    ADM          ADM  Consumer Staples         NaN       1.0      NaN
#
#    osci_position os_engagement  in_suzy relevance  company_count
# 0            NaN           NaN      NaN       NaN              1
# 1          285.0           NaN      NaN       NaN              1
# 2          276.0           NaN      NaN       NaN              1
# 3            NaN           NaN      NaN       NaN              1
# 4            NaN           NaN      NaN       NaN              1

# %%
print(len(df_partb['company'].unique()))
# Out:
# 876

# %%
df_check = df_partb.groupby(['in_osci','in_sp500','in_suzy','company_count']).count()
df_check
# Out:
#                                         symbol  company  sector  industry  \
# in_osci in_sp500 in_suzy company_count
# 1.0     1.0      1.0     1                   8        8       8         8
#
#                                         osci_position  os_engagement  \
# in_osci in_sp500 in_suzy company_count
# 1.0     1.0      1.0     1                          8              3
#
#                                         relevance
# in_osci in_sp500 in_suzy company_count
# 1.0     1.0      1.0     1                      3

# %% [markdown]
# ### 4. Data Source:  OSPO Landscape(ToDo Group)
# https://landscape.todogroup.org

# %%
file_name = 'ospo_todo_landscape.csv'

df_ospo = pd.read_csv('data_raw/'+file_name)
df_ospo['in_ospo']=1

print(df_ospo.shape)
df_ospo.head(3)
# Out:
# (225, 41)
#              Name Organization                       Homepage  \
# 0  Adobe (Member)        Adobe         https://www.adobe.com/
# 1  Aiven (Member)        Aiven      https://github.com/aiven/
# 2  Apple (Member)        Apple  https://opensource.apple.com/
#
#                                                 Logo  \
# 0  https://landscape.todogroup.org/logos/adobe-me...
# 1  https://landscape.todogroup.org/logos/aiven-me...
# 2  https://landscape.todogroup.org/logos/apple-me...
#
#                         Twitter  \
# 0     https://twitter.com/Adobe
# 1  https://twitter.com/aiven_io
# 2     https://twitter.com/apple
#
#                                   Crunchbase URL    Market Cap Ticker  \
# 0  https://www.crunchbase.com/organization/adobe  1.887401e+11   ADBE
# 1  https://www.crunchbase.com/organization/aiven           NaN    NaN
# 2  https://www.crunchbase.com/organization/apple  2.608140e+12   AAPL
#
#         Funding   Member Relation        License           Headquarters  \
# 0  2.500000e+06  General   member  NotOpenSource   San Jose, California
# 1  2.100000e+08  General   member  NotOpenSource      Helsinki, Finland
# 2  6.150230e+09  General   member  NotOpenSource  Cupertino, California
#
#      Latest Tweet Date                                        Description  \
# 0  2022-05-04 13:00:38  Adobe is a software company that provides its ...
# 1  2022-05-04 11:33:18  Aiven is an information technology company tha...
# 2                  NaN  Apple is a multinational corporation that desi...
#
#                               Crunchbase Description   Crunchbase Homepage  \
# 0  Adobe is a software company that provides its ...  http://www.adobe.com
# 1  Aiven is an information technology company tha...      https://aiven.io
# 2  Apple is a multinational corporation that desi...  http://www.apple.com
#
#   Crunchbase City Crunchbase Region Crunchbase Country  \
# 0        San Jose        California      United States
# 1        Helsinki  Southern Finland            Finland
# 2       Cupertino        California      United States
#
#              Crunchbase Twitter                      Crunchbase Linkedin  \
# 0      http://twitter.com/Adobe   https://www.linkedin.com/company/adobe
# 1  https://twitter.com/aiven_io  https://www.linkedin.com/company/aiven/
# 2     https://twitter.com/apple   https://www.linkedin.com/company/apple
#
#   Crunchbase Ticker Crunchbase Kind  Crunchbase Min Employees  \
# 0              ADBE      market_cap                   10001.0
# 1               NaN         funding                     251.0
# 2              AAPL      market_cap                   10001.0
#
#    Crunchbase Max Employees           Category Subcategory    OSS Github Repo  \
# 0                 1000000.0  TODO Group Member     General  False         NaN
# 1                     500.0  TODO Group Member     General  False         NaN
# 2                 1000000.0  TODO Group Member     General  False         NaN
#
#    Github Stars Github Description  Github Latest Commit Date  \
# 0           NaN                NaN                        NaN
# 1           NaN                NaN                        NaN
# 2           NaN                NaN                        NaN
#
#   Github Latest Commit Link Github Release Date Github Release Link  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
#
#   Github Start Commit Date Github Start Commit Link  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
#
#    Github Contributors Count Github Contributors Link  in_ospo
# 0                        NaN                      NaN        1
# 1                        NaN                      NaN        1
# 2                        NaN                      NaN        1

# %%
df_ospo = df_ospo.rename(columns=
                         {'Organization': 'company',
                          'Ticker': 'symbol_ospo',
                          'Market Cap': 'market_cap',
                          'Crunchbase Country': 'country',
                          'License': 'license'
                             })

keep_cols = ['company', 'symbol_ospo','market_cap', 'country', 'relevance',
             'in_ospo'
            ]

df_ospo = df_ospo.filter(keep_cols)


print(df_ospo.shape)
df_ospo.head(3)
# Out:
# (225, 5)
#   company symbol_ospo    market_cap        country  in_ospo
# 0   Adobe        ADBE  1.887401e+11  United States        1
# 1   Aiven         NaN           NaN        Finland        1
# 2   Apple        AAPL  2.608140e+12  United States        1

# %%
#df_ospo

# %%
print(len(df_ospo['company'].unique()))
# Out:
# 117

# %% [markdown]
# # NEXT STEPS
# - rename vars in ospo dataframe
# - merge ospo data in
# - sort and check company names

# %%
df_check = df_ospo.groupby(['in_ospo']).count()
df_check
# Out:
#          company  symbol_ospo  market_cap  country
# in_ospo
# 1            225          133         133      225

# %%
df_partc = df_partb.merge(df_ospo, left_on="company", right_on="company", how="outer")
df_partc['company_count']=1
print(df_partc.shape)
df_partc.head()
# Out:
# (1039, 15)
#   symbol      company            sector    industry  in_sp500  in_osci  \
# 0    MMM           3M       Industrials         NaN       1.0      NaN
# 1    NaN    4teamwork               NaN  Technology       NaN      1.0
# 2    NaN       5minds               NaN  Technology       NaN      1.0
# 3    AOS  A. O. Smith       Industrials         NaN       1.0      NaN
# 4    ADM          ADM  Consumer Staples         NaN       1.0      NaN
#
#    osci_position os_engagement  in_suzy relevance  company_count symbol_ospo  \
# 0            NaN           NaN      NaN       NaN              1         NaN
# 1          285.0           NaN      NaN       NaN              1         NaN
# 2          276.0           NaN      NaN       NaN              1         NaN
# 3            NaN           NaN      NaN       NaN              1         NaN
# 4            NaN           NaN      NaN       NaN              1         NaN
#
#    market_cap country  in_ospo
# 0         NaN     NaN      NaN
# 1         NaN     NaN      NaN
# 2         NaN     NaN      NaN
# 3         NaN     NaN      NaN
# 4         NaN     NaN      NaN

# %%
print(len(df_partc['company'].unique()))
# Out:
# 931

# %%
df_check = df_partc.groupby(['in_sp500', 'in_osci', 'in_suzy', 'in_ospo','company_count']).count()
df_check
# Out:
#                                                 symbol  company  sector  \
# in_sp500 in_osci in_suzy in_ospo company_count
# 1.0      1.0     1.0     1.0     1                  10       10      10
#
#                                                 industry  osci_position  \
# in_sp500 in_osci in_suzy in_ospo company_count
# 1.0      1.0     1.0     1.0     1                    10             10
#
#                                                 os_engagement  relevance  \
# in_sp500 in_osci in_suzy in_ospo company_count
# 1.0      1.0     1.0     1.0     1                          4          4
#
#                                                 symbol_ospo  market_cap  \
# in_sp500 in_osci in_suzy in_ospo company_count
# 1.0      1.0     1.0     1.0     1                       10          10
#
#                                                 country
# in_sp500 in_osci in_suzy in_ospo company_count
# 1.0      1.0     1.0     1.0     1                   10

# %%
df_partc
# Out:
#      symbol                                   company                  sector  \
# 0       MMM                                        3M             Industrials
# 1       NaN                                 4teamwork                     NaN
# 2       NaN                                    5minds                     NaN
# 3       AOS                               A. O. Smith             Industrials
# 4       ADM                                       ADM        Consumer Staples
# 5       AES                                  AES Corp               Utilities
# 6       NaN                                       AMD                     NaN
# 7       APA                           APA Corporation                  Energy
# 8       NaN                                       ARM                     NaN
# 9         T                                      AT&T  Communication Services
# 10     ABBV                                    AbbVie             Health Care
# 11      ABT                       Abbott Laboratories             Health Care
# 12      NaN                                   Abilian                     NaN
# 13     ABMD                                   Abiomed             Health Care
# 14      ACN                                 Accenture  Information Technology
# 15      NaN                                    Acsone                     NaN
# 16     ATVI                       Activision Blizzard  Communication Services
# 17      NaN                                    Ad Hoc                     NaN
# 18      NaN                                   Adguard                     NaN
# 19     ADBE                                     Adobe  Information Technology
# 20     ADBE                                     Adobe  Information Technology
# 21      AAP                        Advance Auto Parts  Consumer Discretionary
# 22      AMD                    Advanced Micro Devices  Information Technology
# 23      AFL                                     Aflac              Financials
# 24      NaN                                    Agaric                     NaN
# 25        A                      Agilent Technologies             Health Care
# 26      APD                  Air Products & Chemicals               Materials
# 27     AKAM                       Akamai Technologies  Information Technology
# 28      NaN                                   Akvelon                     NaN
# 29      ALK                          Alaska Air Group             Industrials
# 30      ALB                     Albemarle Corporation               Materials
# 31      ARE           Alexandria Real Estate Equities             Real Estate
# 32      NaN                                  Alfresco                     NaN
# 33      NaN                                   Algolia                     NaN
# 34      NaN                                   Alibaba                     NaN
# 35     ALGN                          Align Technology             Health Care
# 36     ALLE                                  Allegion             Industrials
# 37      LNT                            Alliant Energy               Utilities
# 38      ALL                             Allstate Corp              Financials
# 39    GOOGL                        Alphabet (Class A)  Communication Services
# 40     GOOG                        Alphabet (Class C)  Communication Services
# 41       MO                              Altria Group        Consumer Staples
# 42     AMZN                                    Amazon  Consumer Discretionary
# 43     AMCR                                     Amcor               Materials
# 44      AEE                               Ameren Corp               Utilities
# 45      AAL                   American Airlines Group             Industrials
# 46      AEP                   American Electric Power               Utilities
# 47      AXP                          American Express              Financials
# 48      AIG              American International Group              Financials
# 49      AMT                            American Tower             Real Estate
# 50      AWK                      American Water Works               Utilities
# 51      AMP                      Ameriprise Financial              Financials
# 52      ABC                         AmerisourceBergen             Health Care
# 53      AME                                    Ametek             Industrials
# 54     AMGN                                     Amgen             Health Care
# 55      APH                                  Amphenol  Information Technology
# 56      ADI                            Analog Devices  Information Technology
# 57      NaN                                    Andela                     NaN
# 58     ANSS                                     Ansys  Information Technology
# 59      NaN                             Ant Financial                     NaN
# 60     ANTM                                    Anthem             Health Care
# 61      NaN                                  Antmicro                     NaN
# 62      AON                                       Aon              Financials
# 63     AAPL                                     Apple  Information Technology
# 64     AAPL                                     Apple  Information Technology
# 65     AMAT                         Applied Materials  Information Technology
# 66     APTV                                     Aptiv  Consumer Discretionary
# 67      NaN                                  ArangoDB                     NaN
# 68      NaN                                  Arbisoft                     NaN
# 69     ANET                           Arista Networks  Information Technology
# 70      AJG                 Arthur J. Gallagher & Co.              Financials
# 71      AIZ                                  Assurant              Financials
# 72      NaN                                 Atlassian                     NaN
# 73      ATO                              Atmos Energy               Utilities
# 74      NaN                                   Atomist                     NaN
# 75      NaN                                    Atypon                     NaN
# 76      AZO                                  AutoZone  Consumer Discretionary
# 77     ADSK                                  Autodesk  Information Technology
# 78     ADSK                                  Autodesk  Information Technology
# 79      ADP                 Automatic Data Processing  Information Technology
# 80      NaN                                Automattic                     NaN
# 81      NaN                                Autonomous                     NaN
# 82      AVB                     AvalonBay Communities             Real Estate
# 83      AVY                            Avery Dennison               Materials
# 84      NaN                                    Azavea                     NaN
# 85      NaN                                      B2CK                     NaN
# 86      NaN                                       BBC                     NaN
# 87      NaN                                     BJISS                     NaN
# 88       BK                                BNY Mellon              Financials
# 89      NaN                                     Baidu                     NaN
# 90      NaN                                     Baidu                     NaN
# 91      BKR                              Baker Hughes                  Energy
# 92      NaN                                    Balena                     NaN
# 93      BLL                                 Ball Corp               Materials
# 94      BAC                           Bank of America              Financials
# 95     BBWI                    Bath & Body Works Inc.  Consumer Discretionary
# 96      BAX                      Baxter International             Health Care
# 97      BDX                          Becton Dickinson             Health Care
# 98      NaN                 Belledonne Communications                     NaN
# 99    BRK.B                        Berkshire Hathaway              Financials
# 100     BBY                                  Best Buy  Consumer Discretionary
# 101     NaN                              Binary Group                     NaN
# 102     BIO                      Bio-Rad Laboratories             Health Care
# 103    TECH                                Bio-Techne             Health Care
# 104    BIIB                                    Biogen             Health Care
# 105     NaN                                   Bitnami                     NaN
# 106     NaN                                   Bitrise                     NaN
# 107     NaN                                     Bjerk                     NaN
# 108     BLK                                 BlackRock              Financials
# 109     BLK                                 BlackRock              Financials
# 110     NaN                                 Block.one                     NaN
# 111     NaN                        Blockchain Foundry                     NaN
# 112     NaN                                 Bloomberg                     NaN
# 113     NaN                                 Bloomberg                     NaN
# 114      BA                                    Boeing             Industrials
# 115    BKNG                          Booking Holdings  Consumer Discretionary
# 116     NaN                                   Bootlin                     NaN
# 117     BWA                                BorgWarner  Consumer Discretionary
# 118     NaN                                     Bosch                     NaN
# 119     NaN                                     Bosch                     NaN
# 120     BXP                         Boston Properties             Real Estate
# 121     BSX                         Boston Scientific             Health Care
# 122     NaN                                     Brave                     NaN
# 123     BMY                      Bristol Myers Squibb             Health Care
# 124    AVGO                                  Broadcom  Information Technology
# 125      BR            Broadridge Financial Solutions  Information Technology
# 126     BRO                             Brown & Brown              Financials
# 127    BF.B                              Brown–Forman        Consumer Staples
# 128     NaN                                   Buoyant                     NaN
# 129     NaN                              Buro Happold                     NaN
# 130    CHRW                            C. H. Robinson             Industrials
# 131    CBRE                                      CBRE             Real Estate
# 132     CDW                                       CDW  Information Technology
# 133      CF                             CF Industries               Materials
# 134     NaN                                       CGI                     NaN
# 135     NaN                                  CKSource                     NaN
# 136     CME                                 CME Group              Financials
# 137     CMS                                CMS Energy               Utilities
# 138     NaN                                  CS Group                     NaN
# 139     CSX                                       CSX             Industrials
# 140     CVS                                CVS Health             Health Care
# 141    CDNS                    Cadence Design Systems  Information Technology
# 142     CZR                     Caesars Entertainment  Consumer Discretionary
# 143     CPB                             Campbell Soup        Consumer Staples
# 144     NaN                                Camptocamp                     NaN
# 145     NaN                                   Camunda                     NaN
# 146     NaN                                   Camunda                     NaN
# 147     NaN                                 Canonical                     NaN
# 148     NaN                                 Capgemini                     NaN
# 149     COF                     Capital One Financial              Financials
# 150     KMX                                    CarMax  Consumer Discretionary
# 151     CAH                           Cardinal Health             Health Care
# 152     CCL                      Carnival Corporation  Consumer Discretionary
# 153    CARR                            Carrier Global             Industrials
# 154    CTLT                                  Catalent             Health Care
# 155     CAT                               Caterpillar             Industrials
# 156    CBOE                       Cboe Global Markets              Financials
# 157      CE                                  Celanese               Materials
# 158     CNC                       Centene Corporation             Health Care
# 159     CNP                        CenterPoint Energy               Utilities
# 160     NaN                                  Centreon                     NaN
# 161    CDAY                                  Ceridian  Information Technology
# 162    CERN                                    Cerner             Health Care
# 163     CRL                Charles River Laboratories             Health Care
# 164    SCHW                Charles Schwab Corporation              Financials
# 165    CHTR                    Charter Communications  Communication Services
# 166     NaN                                      Chef                     NaN
# 167     CVX                       Chevron Corporation                  Energy
# 168     CMG                    Chipotle Mexican Grill  Consumer Discretionary
# 169      CB                                     Chubb              Financials
# 170     CHD                           Church & Dwight        Consumer Staples
# 171      CI                                     Cigna             Health Care
# 172    CINF                      Cincinnati Financial              Financials
# 173    CTAS                        Cintas Corporation             Industrials
# 174     NaN                                  CircleCI                     NaN
# 175    CSCO                             Cisco Systems  Information Technology
# 176       C                                 Citigroup              Financials
# 177     CFG                  Citizens Financial Group              Financials
# 178     NaN                                    Citrix                     NaN
# 179    CTXS                            Citrix Systems  Information Technology
# 180     CLX                                    Clorox        Consumer Staples
# 181     NaN                               CloudCannon                     NaN
# 182     NaN                                 Cloudbees                     NaN
# 183     NaN                                  Cloudera                     NaN
# 184     NaN                                 Cloudfare                     NaN
# 185      KO                         Coca-Cola Company        Consumer Staples
# 186     NaN                             Cockroachlabs                     NaN
# 187    CTSH            Cognizant Technology Solutions  Information Technology
# 188      CL                         Colgate-Palmolive        Consumer Staples
# 189     NaN                                 Collabora                     NaN
# 190   CMCSA                                   Comcast  Communication Services
# 191   CMCSA                                   Comcast  Communication Services
# 192     CMA                                  Comerica              Financials
# 193     CAG                            Conagra Brands        Consumer Staples
# 194     NaN                                 Confluent                     NaN
# 195     COP                            ConocoPhillips                  Energy
# 196     NaN                                 ConsenSys                     NaN
# 197      ED                       Consolidated Edison               Utilities
# 198     STZ                      Constellation Brands        Consumer Staples
# 199    CPRT                                    Copart             Industrials
# 200     GLW                                   Corning  Information Technology
# 201    CTVA                                   Corteva               Materials
# 202    COST                                    Costco        Consumer Staples
# 203    CTRA                                   Coterra                  Energy
# 204     NaN                                 Couchbase                     NaN
# 205     NaN                                      Cozy                     NaN
# 206     CCI                              Crown Castle             Real Estate
# 207     CMI                                   Cummins             Industrials
# 208     DHI                              D. R. Horton  Consumer Discretionary
# 209     NaN                                       D2L                     NaN
# 210     NaN                                      D2iQ                     NaN
# 211     DTE                                DTE Energy               Utilities
# 212     DXC                            DXC Technology  Information Technology
# 213     DVA                                    DaVita             Health Care
# 214     DHR                       Danaher Corporation             Health Care
# 215     DRI                        Darden Restaurants  Consumer Discretionary
# 216     NaN                                 Datadoghq                     NaN
# 217     NaN                                    Decred                     NaN
# 218      DE                               Deere & Co.             Industrials
# 219     DAL                           Delta Air Lines             Industrials
# 220    XRAY                           Dentsply Sirona             Health Care
# 221     NaN                                Devexperts                     NaN
# 222     DVN                              Devon Energy                  Energy
# 223     NaN                            Devox Software                     NaN
# 224    DXCM                                    DexCom             Health Care
# 225    FANG                        Diamondback Energy                  Energy
# 226     NaN                             Digital Asset                     NaN
# 227     NaN                            Digital Bazaar                     NaN
# 228     DLR                      Digital Realty Trust             Real Estate
# 229     NaN                                    Dimagi                     NaN
# 230     DFS               Discover Financial Services              Financials
# 231   DISCA                      Discovery (Series A)  Communication Services
# 232   DISCK                      Discovery (Series C)  Communication Services
# 233    DISH                              Dish Network  Communication Services
# 234     NaN                                    Docker                     NaN
# 235      DG                            Dollar General  Consumer Discretionary
# 236    DLTR                               Dollar Tree  Consumer Discretionary
# 237       D                           Dominion Energy               Utilities
# 238     DPZ                            Domino's Pizza  Consumer Discretionary
# 239     DOV                         Dover Corporation             Industrials
# 240     DOW                                       Dow               Materials
# 241      DD                                    DuPont               Materials
# 242     DUK                               Duke Energy               Utilities
# 243     DRE                          Duke Realty Corp             Real Estate
# 244     NaN                                 Dynatrace                     NaN
# 245     NaN                                 Dynatrace                     NaN
# 246     EOG                             EOG Resources                  Energy
# 247     NaN                                      EPAM                     NaN
# 248     NaN                                      ESRI                     NaN
# 249     NaN                                East Agile                     NaN
# 250     EMN                          Eastman Chemical               Materials
# 251     ETN                         Eaton Corporation             Industrials
# 252     ECL                                    Ecolab               Materials
# 253     EIX                      Edison International               Utilities
# 254      EW                      Edwards Lifesciences             Health Care
# 255     NaN                                   Eficent                     NaN
# 256     NaN                                   Elastic                     NaN
# 257     NaN                                   Elastic                     NaN
# 258      EA                           Electronic Arts  Communication Services
# 259     LLY                            Eli Lilly & Co             Health Care
# 260     EMR                  Emerson Electric Company             Industrials
# 261     NaN                                   Enalean                     NaN
# 262     NaN                                  Endlessm                     NaN
# 263    ENPH                            Enphase Energy  Information Technology
# 264     ETR                                   Entergy               Utilities
# 265     EFX                                   Equifax             Industrials
# 266    EQIX                                   Equinix             Real Estate
# 267    EQIX                                   Equinix             Real Estate
# 268     NaN                                   Equinor                     NaN
# 269     EQR                        Equity Residential             Real Estate
# 270     NaN                                  Ericsson                     NaN
# 271     NaN                                  Ericsson                     NaN
# 272     NaN                                 Espressif                     NaN
# 273     ESS                      Essex Property Trust             Real Estate
# 274      EL                    Estée Lauder Companies        Consumer Staples
# 275    ETSY                                      Etsy  Consumer Discretionary
# 276     NaN                                 EuroLinux                     NaN
# 277      RE                                Everest Re              Financials
# 278    EVRG                                    Evergy               Utilities
# 279      ES                         Eversource Energy               Utilities
# 280     EXC                                    Exelon               Utilities
# 281     NaN                               Exoplatform                     NaN
# 282    EXPE                             Expedia Group  Consumer Discretionary
# 283    EXPD                                Expeditors             Industrials
# 284     EXR                       Extra Space Storage             Real Estate
# 285     XOM                                ExxonMobil                  Energy
# 286    FFIV                               F5 Networks  Information Technology
# 287     FMC                           FMC Corporation               Materials
# 288      FB                                  Facebook  Communication Services
# 289    FAST                                  Fastenal             Industrials
# 290     FDX                                     FedEx             Industrials
# 291     FRT           Federal Realty Investment Trust             Real Estate
# 292     FIS    Fidelity National Information Services  Information Technology
# 293    FITB                       Fifth Third Bancorp              Financials
# 294     NaN                           Financial Times                     NaN
# 295     NaN                                 Finbourne                     NaN
# 296     FRC                       First Republic Bank              Financials
# 297      FE                               FirstEnergy               Utilities
# 298    FISV                                    Fiserv  Information Technology
# 299     NaN                           Flatiron school                     NaN
# 300     FLT                                  Fleetcor  Information Technology
# 301       F                                      Ford  Consumer Discretionary
# 302     NaN                               Forestry.io                     NaN
# 303    FTNT                                  Fortinet  Information Technology
# 304     FTV                                   Fortive             Industrials
# 305    FBHS            Fortune Brands Home & Security             Industrials
# 306    FOXA                 Fox Corporation (Class A)  Communication Services
# 307     FOX                 Fox Corporation (Class B)  Communication Services
# 308     BEN                        Franklin Resources              Financials
# 309     FCX                          Freeport-McMoRan               Materials
# 310     NaN                            Galera Cluster                     NaN
# 311     GPS                                       Gap  Consumer Discretionary
# 312    GRMN                                    Garmin  Consumer Discretionary
# 313      IT                                   Gartner  Information Technology
# 314     NaN                                  GatsbyJS                     NaN
# 315    GNRC                          Generac Holdings             Industrials
# 316      GD                          General Dynamics             Industrials
# 317      GE                          General Electric             Industrials
# 318     GIS                             General Mills        Consumer Staples
# 319      GM                            General Motors  Consumer Discretionary
# 320     GPC                             Genuine Parts  Consumer Discretionary
# 321     NaN                               Giant Swarm                     NaN
# 322    GILD                           Gilead Sciences             Health Care
# 323     NaN                                    GitHub                     NaN
# 324     NaN                                    GitHub                     NaN
# 325     NaN                                    GitHub                     NaN
# 326     NaN                                    GitLab                     NaN
# 327     NaN                                    GitLab                     NaN
# 328     NaN                                    GitLab                     NaN
# 329     NaN                                    GitLab                     NaN
# 330     NaN                                    GitLab                     NaN
# 331     NaN                                    GitLab                     NaN
# 332     GPN                           Global Payments  Information Technology
# 333      GL                                Globe Life              Financials
# 334     NaN                                    Gofore                     NaN
# 335     NaN                          Golden Dimension                     NaN
# 336      GS                             Goldman Sachs              Financials
# 337      GS                             Goldman Sachs              Financials
# 338     NaN                                    Google                     NaN
# 339     NaN                                    Google                     NaN
# 340     NaN                                    Google                     NaN
# 341     NaN                                    Gradle                     NaN
# 342     NaN                                   Grafana                     NaN
# 343     NaN                                   Graylog                     NaN
# 344     NaN                                    H2O.ai                     NaN
# 345     HCA                            HCA Healthcare             Health Care
# 346     NaN                                      HERE                     NaN
# 347     HPQ                                        HP  Information Technology
# 348     HAL                               Halliburton                  Energy
# 349     HBI                               Hanesbrands  Consumer Discretionary
# 350     HAS                                    Hasbro  Consumer Discretionary
# 351     NaN                                 HashiCorp                     NaN
# 352    PEAK                     Healthpeak Properties             Real Estate
# 353    HSIC                              Henry Schein             Health Care
# 354     HES                          Hess Corporation                  Energy
# 355     HPE                Hewlett Packard Enterprise  Information Technology
# 356     HPE                Hewlett Packard Enterprise  Information Technology
# 357     HLT                          Hilton Worldwide  Consumer Discretionary
# 358    HOLX                                   Hologic             Health Care
# 359      HD                                Home Depot  Consumer Discretionary
# 360     HON                                 Honeywell             Industrials
# 361     HRL                                    Hormel        Consumer Staples
# 362     HST                     Host Hotels & Resorts             Real Estate
# 363     HWM                          Howmet Aerospace             Industrials
# 364     NaN                                    Huawei                     NaN
# 365     HUM                                    Humana             Health Care
# 366    HBAN                     Huntington Bancshares              Financials
# 367     HII             Huntington Ingalls Industries             Industrials
# 368     IBM                                       IBM  Information Technology
# 369     IBM                                       IBM  Information Technology
# 370     IEX                          IDEX Corporation             Industrials
# 371    INFO                                IHS Markit             Industrials
# 372    IPGP                             IPG Photonics  Information Technology
# 373     IQV                                     IQVIA             Health Care
# 374    IDXX                        Idexx Laboratories             Health Care
# 375     NaN                                    Igalia                     NaN
# 376     ITW                       Illinois Tool Works             Industrials
# 377    ILMN                                  Illumina             Health Care
# 378     NaN                                Improbable                     NaN
# 379    INCY                                    Incyte             Health Care
# 380     NaN                                 Indexdata                     NaN
# 381     NaN                                 Infosiftr                     NaN
# 382     NaN                              Infragistics                     NaN
# 383      IR                            Ingersoll Rand             Industrials
# 384     NaN                      Insolar Technologies                     NaN
# 385     NaN                               Instructure                     NaN
# 386    INTC                                     Intel  Information Technology
# 387    INTC                                     Intel  Information Technology
# 388     ICE                 Intercontinental Exchange              Financials
# 389     IFF        International Flavors & Fragrances               Materials
# 390      IP                       International Paper               Materials
# 391     IPG                         Interpublic Group  Communication Services
# 392    INTU                                    Intuit  Information Technology
# 393    ISRG                        Intuitive Surgical             Health Care
# 394     IVZ                                   Invesco              Financials
# 395     NaN                                      Iohk                     NaN
# 396     IRM                             Iron Mountain             Real Estate
# 397    JBHT                                J. B. Hunt             Industrials
# 398     SJM                                JM Smucker        Consumer Staples
# 399     JPM                            JPMorgan Chase              Financials
# 400    JKHY                   Jack Henry & Associates  Information Technology
# 401       J                  Jacobs Engineering Group             Industrials
# 402     NaN                               JankariTech                     NaN
# 403     NaN                                 JetBrains                     NaN
# 404     JNJ                         Johnson & Johnson             Health Care
# 405     JCI                          Johnson Controls             Industrials
# 406     NaN                                    Joyent                     NaN
# 407     NaN                           Julia Computing                     NaN
# 408    JNPR                          Juniper Networks  Information Technology
# 409    KLAC                           KLA Corporation  Information Technology
# 410     NaN                                    Kainos                     NaN
# 411     NaN                                     Kakao                     NaN
# 412     NaN                                   Kaltura                     NaN
# 413     KSU                      Kansas City Southern             Industrials
# 414       K                                 Kellogg's        Consumer Staples
# 415     KEY                                   KeyCorp              Financials
# 416    KEYS                     Keysight Technologies  Information Technology
# 417     KMB                            Kimberly-Clark        Consumer Staples
# 418     KIM                              Kimco Realty             Real Estate
# 419     KMI                             Kinder Morgan                  Energy
# 420     NaN                                   Kinvolk                     NaN
# 421     NaN                                   Kitware                     NaN
# 422     KHC                               Kraft Heinz        Consumer Staples
# 423      KR                                    Kroger        Consumer Staples
# 424     LHX                     L3Harris Technologies             Industrials
# 425     NaN                            LG Electronics                     NaN
# 426     NaN                          LINE Corporation                     NaN
# 427     LKQ                           LKQ Corporation  Consumer Discretionary
# 428      LH                                   LabCorp             Health Care
# 429     NaN                                    LabKey                     NaN
# 430    LRCX                              Lam Research  Information Technology
# 431      LW                               Lamb Weston        Consumer Staples
# 432     LVS                           Las Vegas Sands  Consumer Discretionary
# 433     LEG                           Leggett & Platt  Consumer Discretionary
# 434    LDOS                                    Leidos             Industrials
# 435     LEN                                    Lennar  Consumer Discretionary
# 436     NaN                                   Liferay                     NaN
# 437     NaN                                Lightcurve                     NaN
# 438     NaN                                  Linagora                     NaN
# 439     NaN                                    Linaro                     NaN
# 440     LNC                          Lincoln National              Financials
# 441     LIN                                     Linde               Materials
# 442     NaN                                  LinkedIn                     NaN
# 443     NaN                                Linutronix                     NaN
# 444     LYV                 Live Nation Entertainment  Communication Services
# 445     LMT                           Lockheed Martin             Industrials
# 446       L                         Loews Corporation              Financials
# 447     NaN                               Loodos Tech                     NaN
# 448     LOW                                    Lowe's  Consumer Discretionary
# 449    LUMN                        Lumen Technologies  Communication Services
# 450     NaN                                    LunarG                     NaN
# 451     NaN                                    Luxoft                     NaN
# 452     NaN                                      Lyft                     NaN
# 453     NaN                                      Lynx                     NaN
# 454     LYB                            LyondellBasell               Materials
# 455     MTB                                  M&T Bank              Financials
# 456     MGM                 MGM Resorts International  Consumer Discretionary
# 457    MSCI                                      MSCI              Financials
# 458     NaN                                 Made Tech                     NaN
# 459     NaN                             ManpowerGroup                     NaN
# 460     NaN                                    Mapbox                     NaN
# 461     MRO                              Marathon Oil                  Energy
# 462     MPC                        Marathon Petroleum                  Energy
# 463     NaN                                   MariaDB                     NaN
# 464    MKTX                               MarketAxess              Financials
# 465     MAR                    Marriott International  Consumer Discretionary
# 466     MMC                          Marsh & McLennan              Financials
# 467     MLM                 Martin Marietta Materials               Materials
# 468     MAS                                     Masco             Industrials
# 469      MA                                Mastercard  Information Technology
# 470    MTCH                               Match Group  Communication Services
# 471     NaN                              Maykin Media                     NaN
# 472     MKC                       McCormick & Company        Consumer Staples
# 473     MCD                                McDonald's  Consumer Discretionary
# 474     MCK                      McKesson Corporation             Health Care
# 475     NaN                                  MediaTek                     NaN
# 476     MDT                                 Medtronic             Health Care
# 477     NaN                     Mellanox Technologies                     NaN
# 478     NaN                                    Mendix                     NaN
# 479     MRK                               Merck & Co.             Health Care
# 480     MET                                   MetLife              Financials
# 481     MTD                            Mettler Toledo             Health Care
# 482    MCHP                      Microchip Technology  Information Technology
# 483      MU                         Micron Technology  Information Technology
# 484    MSFT                                 Microsoft  Information Technology
# 485    MSFT                                 Microsoft  Information Technology
# 486     MAA                    Mid-America Apartments             Real Estate
# 487    MRNA                                   Moderna             Health Care
# 488     MHK                         Mohawk Industries  Consumer Discretionary
# 489     TAP             Molson Coors Beverage Company        Consumer Staples
# 490    MDLZ                    Mondelez International        Consumer Staples
# 491    MPWR                  Monolithic Power Systems  Information Technology
# 492    MNST                          Monster Beverage        Consumer Staples
# 493     MCO                       Moody's Corporation              Financials
# 494      MS                            Morgan Stanley              Financials
# 495     NaN                            Motion Picture                     NaN
# 496     MSI                        Motorola Solutions  Information Technology
# 497     NaN                                   Mozilla                     NaN
# 498     NaN                                  MuleSoft                     NaN
# 499     NRG                                NRG Energy               Utilities
# 500     NVR                                       NVR  Consumer Discretionary
# 501     NaN                                    NVidia                     NaN
# 502    NXPI                                       NXP  Information Technology
# 503    NDAQ                                    Nasdaq              Financials
# 504     NaN                                  Navigine                     NaN
# 505    NTAP                                    NetApp  Information Technology
# 506    NTAP                                    NetApp  Information Technology
# 507    NFLX                                   Netflix  Communication Services
# 508    NFLX                                   Netflix  Communication Services
# 509     NaN                                    Nevion                     NaN
# 510     NaN                                 New Relic                     NaN
# 511     NWL                             Newell Brands  Consumer Discretionary
# 512     NEM                                   Newmont               Materials
# 513    NWSA                       News Corp (Class A)  Communication Services
# 514     NWS                       News Corp (Class B)  Communication Services
# 515     NaN                                    Nexedi                     NaN
# 516     NEE                            NextEra Energy               Utilities
# 517     NaN                                 Nextcloud                     NaN
# 518      NI                                  NiSource               Utilities
# 519    NLSN                          Nielsen Holdings             Industrials
# 520     NKE                                      Nike  Consumer Discretionary
# 521     NaN                      Nordic Semiconductor                     NaN
# 522     NSC                          Norfolk Southern             Industrials
# 523    NTRS                            Northern Trust              Financials
# 524     NOC                          Northrop Grumman             Industrials
# 525    NLOK                            NortonLifeLock  Information Technology
# 526    NCLH            Norwegian Cruise Line Holdings  Consumer Discretionary
# 527     NUE                                     Nucor               Materials
# 528     NaN                                     Nuxeo                     NaN
# 529    NVDA                                    Nvidia  Information Technology
# 530     NaN                                     Nymea                     NaN
# 531    ORLY                       O'Reilly Automotive  Consumer Discretionary
# 532     NaN                           OCTO Technology                     NaN
# 533     NaN                                ONLYOFFICE                     NaN
# 534     NaN                                   Obvious                     NaN
# 535     OXY                      Occidental Petroleum                  Energy
# 536     NaN                                      Odoo                     NaN
# 537     NaN                                      Okta                     NaN
# 538    ODFL                 Old Dominion Freight Line             Industrials
# 539     OMC                             Omnicom Group  Communication Services
# 540     NaN                                    OnGres                     NaN
# 541     OKE                                     Oneok                  Energy
# 542     NaN                             Open Robotics                     NaN
# 543     NaN                               OpenLattice                     NaN
# 544     NaN                         Opencast Software                     NaN
# 545     NaN                                     Optum                     NaN
# 546     NaN                                     Optum                     NaN
# 547    ORCL                                    Oracle  Information Technology
# 548     NaN                                    Orange                     NaN
# 549     OGN                             Organon & Co.             Health Care
# 550     NaN                                    Origin                     NaN
# 551    OTIS                            Otis Worldwide             Industrials
# 552     PNC                    PNC Financial Services              Financials
# 553     PPG                            PPG Industries               Materials
# 554     PPL                                       PPL               Utilities
# 555     PTC                                       PTC  Information Technology
# 556     NaN                               PTFS Europe                     NaN
# 557     NaN                                 PTV Group                     NaN
# 558     PVH                                       PVH  Consumer Discretionary
# 559    PCAR                                    Paccar             Industrials
# 560     PKG          Packaging Corporation of America               Materials
# 561     NaN                                  Palantir                     NaN
# 562     NaN                        Palo Alto Networks                     NaN
# 563     NaN                                  Pantheon                     NaN
# 564      PH                           Parker-Hannifin             Industrials
# 565    PYPL                                    PayPal  Information Technology
# 566    PYPL                                    PayPal  Information Technology
# 567    PAYX                                   Paychex  Information Technology
# 568    PAYC                                    Paycom  Information Technology
# 569    PENN                      Penn National Gaming  Consumer Discretionary
# 570     PNR                                   Pentair             Industrials
# 571    PBCT                 People's United Financial              Financials
# 572     PEP                                   PepsiCo        Consumer Staples
# 573     NaN                                   Percona                     NaN
# 574     PKI                               PerkinElmer             Health Care
# 575     PFE                                    Pfizer             Health Care
# 576      PM               Philip Morris International        Consumer Staples
# 577     NaN                                   Philips                     NaN
# 578     PSX                               Phillips 66                  Energy
# 579     NaN                                      Pilz                     NaN
# 580     NaN                                   PingCAP                     NaN
# 581     PNW                     Pinnacle West Capital               Utilities
# 582     PXD                 Pioneer Natural Resources                  Energy
# 583     NaN                                   Pivotal                     NaN
# 584     NaN                             Pixel & Tonic                     NaN
# 585     NaN                                    Plotly                     NaN
# 586     NaN                                   Polidea                     NaN
# 587     NaN                                   Polyapp                     NaN
# 588    POOL                          Pool Corporation  Consumer Discretionary
# 589     NaN                                     Povio                     NaN
# 590     PFG                 Principal Financial Group              Financials
# ...
# 768           VZ  1.994409e+11    United States      1.0
# 769          NaN           NaN              NaN      NaN
# 770          NaN           NaN              NaN      NaN
# 771          NaN           NaN              NaN      NaN
# 772          NaN           NaN              NaN      NaN
# 773          NaN           NaN              NaN      NaN
# 774          NaN           NaN              NaN      NaN
# 775          NaN           NaN              NaN      NaN
# 776          NaN           NaN              NaN      NaN
# 777          NaN           NaN              NaN      NaN
# 778          NaN           NaN              NaN      NaN
# 779          NaN           NaN              NaN      NaN
# 780          NaN           NaN              NaN      NaN
# 781          NaN           NaN              NaN      NaN
# 782          NaN           NaN              NaN      NaN
# 783          NaN           NaN              NaN      NaN
# 784          NaN           NaN              NaN      NaN
# 785          NaN           NaN              NaN      NaN
# 786          NaN           NaN              NaN      NaN
# 787          NaN           NaN              NaN      NaN
# 788          NaN           NaN              NaN      NaN
# 789          NaN           NaN              NaN      NaN
# 790        WDC.F  2.017250e+10    United States      1.0
# 791        WDC.F  2.017250e+10    United States      1.0
# 792          NaN           NaN              NaN      NaN
# 793          NaN           NaN              NaN      NaN
# 794          NaN           NaN              NaN      NaN
# 795          NaN           NaN              NaN      NaN
# 796          NaN           NaN              NaN      NaN
# 797          NaN           NaN    United States      1.0
# 798          NaN           NaN              NaN      NaN
# 799          NaN           NaN              NaN      NaN
# 800          NaN           NaN              NaN      NaN
# 801          NaN           NaN              NaN      NaN
# 802          NaN           NaN              NaN      NaN
# 803      XLNX.VI  4.865317e+10    United States      1.0
# 804      XLNX.VI  4.865317e+10    United States      1.0
# 805          NaN           NaN              NaN      NaN
# 806          NaN           NaN              NaN      NaN
# 807          NaN           NaN              NaN      NaN
# 808          NaN           NaN              NaN      NaN
# 809          NaN           NaN              NaN      NaN
# 810          NaN           NaN              NaN      NaN
# 811       ZAL.DE  1.010323e+10          Germany      1.0
# 812          NaN           NaN              NaN      NaN
# 813          NaN           NaN              NaN      NaN
# 814          NaN           NaN              NaN      NaN
# 815          NaN           NaN              NaN      NaN
# 816          NaN           NaN              NaN      NaN
# 817          NaN           NaN              NaN      NaN
# 818         EBAY  3.027038e+10    United States      1.0
# 819         EBAY  3.027038e+10    United States      1.0
# 820          NaN           NaN              NaN      NaN
# 821          NaN           NaN              NaN      NaN
# 822          NaN           NaN              NaN      NaN
# 823          NaN           NaN              NaN      NaN
# 824          NaN           NaN              NaN      NaN
# 825          NaN           NaN              NaN      NaN
# 826          NaN           NaN              NaN      NaN
# 827          NaN           NaN              NaN      NaN
# 828          NaN           NaN              NaN      NaN
# 829          NaN           NaN              NaN      NaN
# 830          NaN           NaN              NaN      NaN
# 831          NaN           NaN              NaN      NaN
# 832          NaN           NaN              NaN      NaN
# 833         DDOG  3.349627e+10    United States      1.0
# 834         DDOG  3.349627e+10    United States      1.0
# 835          NaN           NaN              NaN      NaN
# 836          NaN           NaN              NaN      NaN
# 837          NaN           NaN              NaN      NaN
# 838          NaN           NaN              NaN      NaN
# 839          NaN           NaN              NaN      NaN
# 840          NaN           NaN              NaN      NaN
# 841          NaN           NaN              NaN      NaN
# 842          NaN           NaN              NaN      NaN
# 843          NaN           NaN              NaN      NaN
# 844          NaN           NaN              NaN      NaN
# 845         CHNG  7.388749e+09    United States      1.0
# 846         CHNG  7.388749e+09    United States      1.0
# 847          NaN           NaN              NaN      NaN
# 848          NaN           NaN              NaN      NaN
# 849          NaN           NaN    United States      1.0
# 850          NaN           NaN              NaN      NaN
# 851          BOX  4.402400e+09    United States      1.0
# 852          BOX  4.402400e+09    United States      1.0
# 853          NaN           NaN              NaN      NaN
# 854          NaN           NaN              NaN      NaN
# 855          NaN           NaN              NaN      NaN
# 856          NaN           NaN              NaN      NaN
# 857          NaN           NaN              NaN      NaN
# 858          NaN           NaN              NaN      NaN
# 859          NaN           NaN    United States      1.0
# 860          NaN           NaN    United States      1.0
# 861          NaN           NaN              NaN      NaN
# 862          NaN           NaN              NaN      NaN
# 863          NaN           NaN              NaN      NaN
# 864          NaN           NaN              NaN      NaN
# 865          NaN           NaN              NaN      NaN
# 866          NaN           NaN              NaN      NaN
# 867          NaN           NaN              NaN      NaN
# 868          NaN           NaN              NaN      NaN
# 869          NaN           NaN              NaN      NaN
# 870          NaN           NaN              NaN      NaN
# 871          NaN           NaN              NaN      NaN
# 872          NaN           NaN              NaN      NaN
# 873          NaN           NaN              NaN      NaN
# 874          NaN           NaN              NaN      NaN
# 875          NaN           NaN              NaN      NaN
# 876          NaN           NaN              NaN      NaN
# 877          DBX  8.088215e+09    United States      1.0
# 878          DBX  8.088215e+09    United States      1.0
# 879          NaN           NaN              NaN      NaN
# 880          NaN           NaN              NaN      NaN
# 881          NaN           NaN              NaN      NaN
# 882          NaN           NaN              NaN      NaN
# 883          NaN           NaN              NaN      NaN
# 884          NaN           NaN              NaN      NaN
# 885          NaN           NaN              NaN      NaN
# 886          NaN           NaN              NaN      NaN
# 887          NaN           NaN              NaN      NaN
# 888          NaN           NaN              NaN      NaN
# 889          NaN           NaN    United States      1.0
# 890          NaN           NaN    United States      1.0
# 891          NaN           NaN              NaN      NaN
# 892          NaN           NaN              NaN      NaN
# 893          NaN           NaN              NaN      NaN
# 894          NaN           NaN              NaN      NaN
# 895          NaN           NaN              NaN      NaN
# 896          NaN           NaN              NaN      NaN
# 897          NaN           NaN              NaN      NaN
# 898          NaN           NaN              NaN      NaN
# 899          NaN           NaN              NaN      NaN
# 900          NaN           NaN          Finland      1.0
# 901          NaN           NaN          Finland      1.0
# 902          NaN           NaN              NaN      NaN
# 903          NaN           NaN              NaN      NaN
# 904         PINS  1.473268e+10    United States      1.0
# 905         PINS  1.473268e+10    United States      1.0
# 906          NaN           NaN          Germany      1.0
# 907          NaN           NaN          Germany      1.0
# 908          NaN           NaN              NaN      NaN
# 909          NaN           NaN              NaN      NaN
# 910          NaN           NaN              NaN      NaN
# 911          NaN           NaN              NaN      NaN
# 912          NaN           NaN              NaN      NaN
# 913          NaN           NaN              NaN      NaN
# 914          NaN           NaN              NaN      NaN
# 915         WORK  2.651952e+10    United States      1.0
# 916          NaN           NaN              NaN      NaN
# 917          NaN           NaN              NaN      NaN
# 918          NaN           NaN              NaN      NaN
# 919          NaN           NaN              NaN      NaN
# 920          TGT  1.077022e+11    United States      1.0
# 921          TGT  1.077022e+11    United States      1.0
# 922          NaN           NaN              NaN      NaN
# 923          NaN           NaN              NaN      NaN
# 924          NaN           NaN              NaN      NaN
# 925          NaN           NaN              NaN      NaN
# 926          USB  7.334153e+10    United States      1.0
# 927          NaN           NaN              NaN      NaN
# 928          NaN           NaN              NaN      NaN
# 929          NaN           NaN              NaN      NaN
# 930          NaN           NaN              NaN      NaN
# 931          NaN           NaN              NaN      NaN
# 932          NaN           NaN              NaN      NaN
# 933          NaN           NaN              NaN      NaN
# 934          NaN           NaN              NaN      NaN
# 935          NaN           NaN          Finland      1.0
# 936          NaN           NaN          Finland      1.0
# 937          NaN           NaN   United Kingdom      1.0
# 938          NaN           NaN   United Kingdom      1.0
# 939         MSFT  2.087771e+12    United States      1.0
# 940         MSFT  2.087771e+12    United States      1.0
# 941          NaN           NaN    United States      1.0
# 942          NaN           NaN    United States      1.0
# 943          NaN           NaN           Brazil      1.0
# 944          NaN           NaN           Brazil      1.0
# 945          NaN           NaN          Germany      1.0
# 946          NaN           NaN          Germany      1.0
# 947          COF  5.195379e+10    United States      1.0
# 948          COF  5.195379e+10    United States      1.0
# 949    600941.SS  1.426672e+11            China      1.0
# 950    600941.SS  1.426672e+11            China      1.0
# 951         CSCO  2.082278e+11    United States      1.0
# 952         CSCO  2.082278e+11    United States      1.0
# 953          NaN           NaN    United States      1.0
# 954          NaN           NaN    United States      1.0
# 955          NaN           NaN          Germany      1.0
# 956          NaN           NaN          Germany      1.0
# 957          NaN           NaN    United States      1.0
# 958          NaN           NaN    United States      1.0
# 959         DOCN  4.048073e+09    United States      1.0
# 960         DOCN  4.048073e+09    United States      1.0
# 961         EPAM  1.681204e+10    United States      1.0
# 962         EPAM  1.681204e+10    United States      1.0
# 963         FFIV  1.050285e+10    United States      1.0
# 964         FFIV  1.050285e+10    United States      1.0
# 965         FMCC  4.856598e+08    United States      1.0
# 966         FMCC  4.856598e+08    United States      1.0
# 967          NaN           NaN    United States      1.0
# 968          NaN           NaN    United States      1.0
# 969          NaN           NaN            China      1.0
# 970          NaN           NaN            China      1.0
# 971          NaN           NaN    United States      1.0
# 972          NaN           NaN    United States      1.0
# 973          NaN           NaN            Spain      1.0
# 974          NaN           NaN            Spain      1.0
# 975           FB  5.655126e+11    United States      1.0
# 976           FB  5.655126e+11    United States      1.0
# 977           FB  5.655126e+11    United States      1.0
# 978         NATI  4.715077e+09    United States      1.0
# 979         NATI  4.715077e+09    United States      1.0
# 980          NaN           NaN    United States      1.0
# 981          NaN           NaN    United States      1.0
# 982    688316.SS  2.208463e+08            China      1.0
# 983    688316.SS  2.208463e+08            China      1.0
# 984          NaN           NaN    United States      1.0
# 985          NaN           NaN    United States      1.0
# 986          NaN           NaN    United States      1.0
# 987          NaN           NaN    United States      1.0
# 988          NaN           NaN    United States      1.0
# 989          NaN           NaN    United States      1.0
# 990         SPOT  2.033612e+10           Sweden      1.0
# 991         SPOT  2.033612e+10           Sweden      1.0
# 992         SPOT  2.033612e+10           Sweden      1.0
# 993           TM  2.375508e+11            Japan      1.0
# 994           TM  2.375508e+11            Japan      1.0
# 995          NaN           NaN    United States      1.0
# 996          NaN           NaN    United States      1.0
# 997          WMT  4.214506e+11    United States      1.0
# 998          WMT  4.214506e+11    United States      1.0
# 999            W  9.014573e+09    United States      1.0
# 1000           W  9.014573e+09    United States      1.0
# 1001    WIPRO.NS  3.525762e+10            India      1.0
# 1002    WIPRO.NS  3.525762e+10            India      1.0
# 1003         NaN           NaN    United States      1.0
# 1004         NaN           NaN    United States      1.0
# 1005         NaN           NaN    United States      1.0
# 1006         NaN           NaN    United States      1.0
# 1007         NaN           NaN    United States      1.0
# 1008         NaN           NaN    United States      1.0
# 1009         NaN           NaN    United States      1.0
# 1010         NaN           NaN    United States      1.0
# 1011         NaN           NaN    United States      1.0
# 1012         NaN           NaN    United States      1.0
# 1013         NaN           NaN    United States      1.0
# 1014     9988.HK  2.692284e+11            China      1.0
# 1015         NaN           NaN  The Netherlands      1.0
# 1016          BA  9.035210e+10    United States      1.0
# 1017         NaN           NaN    United States      1.0
# 1018         NaN           NaN    United States      1.0
# 1019        FNMA  8.885331e+08    United States      1.0
# 1020         NaN           NaN            India      1.0
# 1021         NaN           NaN    United States      1.0
# 1022         NaN           NaN          Ireland      1.0
# 1023         NaN           NaN           Sweden      1.0
# 1024         NaN           NaN           Sweden      1.0
# 1025         NaN           NaN           Sweden      1.0
# 1026         NaN           NaN           Sweden      1.0
# 1027         NaN           NaN           Canada      1.0
# 1028         NaN           NaN    United States      1.0
# 1029         NaN           NaN    United States      1.0
# 1030         NaN           NaN           Sweden      1.0
# 1031         NaN           NaN    United States      1.0
# 1032         NaN           NaN    United States      1.0
# 1033         NaN           NaN            Spain      1.0
# 1034         NaN           NaN            Spain      1.0
# 1035         NaN           NaN    United States      1.0
# 1036         NaN           NaN    United States      1.0
# 1037         NaN           NaN    United States      1.0
# 1038         NaN           NaN    United States      1.0

# %%
df_check = df_partc.groupby(['in_sp500']).count()
df_check
# Out:
#           symbol  company  sector  industry  in_osci  osci_position  \
# in_sp500
# 1.0          526      526     526        33       33             33
#
#           os_engagement  in_suzy  relevance  company_count  symbol_ospo  \
# in_sp500
# 1.0                  13       22         13            526           44
#
#           market_cap  country  in_ospo
# in_sp500
# 1.0               44       44       44

# %%
print("Today's date:", current_date)
# Out:
# Today's date: 2022-05-21

# %% [markdown]
# # END OF CODE

# %% [markdown]
# # END OF CODE

# %% [markdown]
# # END OF CODE

# %% [markdown]
# ---

# %%
print x
# Out:
#   File "/var/folders/f5/4hllfzqx6pq2sfm22_khf5400000gn/T/ipykernel_2149/3945978432.py", line 1
#     print x
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x)?

# %% [markdown]
# ### Lux video

# %% [markdown]
# #### Example hands-on Lux tutorial
# https://mybinder.org/v2/gh/lux-org/lux-binder/master?urlpath=lab/tree/demo/hpi_covid_demo.ipynb

# %%
import pandas as pd
#df = pd.read_csv("data.csv")
import lux

df = df_partc.copy()
#df.groupby(" ").mean()["xxx"]

# %%
df_meetup['city'].mask(df_meetup['city'] == 'Raleigh', 'Raleigh-Durham', inplace=True)

# %%
# rename columns
df_meetup.rename(columns={"name": "meetup_name", 
                          "members": "meetup_members",
                          "fullurl": "meetup_url",
                          "created": "meetup_created",
                          "status": "meetup_status"
                            },
                   inplace = True,
                   errors="raise")

# %% [markdown]
# ## 2. Data Source:  Chapter List
# ### Get raw data

# %%
# !ls -alt data_raw/

# %%
file_name = '1_pyladies_export_2021_03_01.csv'

chapter_list = pd.read_csv(datapath+file_name)

# %%
chapter_list.head()

# %%
chapter_list.info()

# %%
chapter_list.shape

# %%
df_chapter = chapter_list.copy()
# rename columns
df_chapter.rename(columns={"First Name [Required]": "city1", 
                             "Last Name [Required]": "city2", 
                             "Email Address [Required]": "email",
                             "Last Sign In [READ ONLY]": "email_signin_date",
                             "Email Usage [READ ONLY]": "email_usage"
                            },
                   inplace = True,
                   errors="raise")


# delete columns:  'active' is same for all
df_chapter = df_chapter.drop(['Status [READ ONLY]'], axis=1)

# fix data issue
df_chapter['city2'].mask(df_chapter['city2'] == \
                      'PyLladies', \
                      'PyLadies', inplace=True)

df_chapter['city2'].mask(df_chapter['city2'] == \
                      'PyLdies', \
                      'PyLadies', inplace=True)

# swap some rows
df_chapter['city_temp1'] = df_chapter['city1'].str.upper() 
df_chapter['city_temp2'] = df_chapter['city2'].str.upper() 

df_chapter['city'] = df_chapter['city1']
df_chapter['temp'] = df_chapter['city2']

df_chapter['city'].mask(df_chapter['city_temp1'] == 'PYLADIES', df_chapter['city2'], inplace=True)

df_chapter['temp'].mask(df_chapter['city_temp2'] == 'PYLADIES', df_chapter['city1'], inplace=True)

# exclude some rows
df_chapter = df_chapter[(df_chapter['city_temp1'] == 'PYLADIES') | (df_chapter['city_temp2'] == 'PYLADIES')] 

df_chapter = df_chapter[(df_chapter['city1'] != 'Admin')] 
df_chapter = df_chapter[(df_chapter['city2'] != 'Sponsorship')] 
df_chapter = df_chapter[(df_chapter['city2'] != 'Info')] 
df_chapter = df_chapter[(df_chapter['city2'] != 'Systems')] 
df_chapter = df_chapter[(df_chapter['city1'] != 'Communications')] 

# clean up city names
df_chapter['city'].mask(df_chapter['city'] == 'NYC', 'New York', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Princeton NJ', 'Princeton', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Pune, India', 'Pune', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'TC', 'Minneapolis', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Goa', 'Panaji Goa', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Visakhapatnam/Andhra Pradesh/India', 'Visakhapatnam', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Washington', 'Washington DC', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Aba / Abia State', 'Aba', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'West Windsor NJ', 'West Windsor', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Medellin', 'Medellín', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Albania', 'Tirania', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'BH', 'Belo Horizonte', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Guatemala', 'Guatemala City', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Inland Empire', 'Riverside', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Vale', 'Vale do Paraiba', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Plateau', 'Jos Plateau', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Recife, Brasil', 'Recife', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Rio de Janerio', 'Rio de Janeirio', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Salt Lake', 'Salt Lake City', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'SA', 'San Antonio', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'São Carlos, Brasil', 'São Carlos', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Taiwan', 'Taipei', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Milan', 'Milano', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Munich', 'München', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Rio de Janeirio', 'Rio de Janeiro', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Bangalore', 'Bengaluru', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'DC', 'Washington DC', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'DF', 'Brasilia', inplace=True)
df_chapter['city'].mask(df_chapter['city'] == 'Congo-Brazzaville', 'Brazzaville', inplace=True)


import datetime
df_chapter['date_logged'] = df_chapter['email_signin_date']

df_chapter['email_signin_date'].mask(df_chapter['email_signin_date'] == 'Never logged in', 'NaN', inplace=True)

df_chapter['email_signin_date'] = df_chapter['email_signin_date'].astype('datetime64[ns]').dt.date

# drop temp variables
df_chapter = df_chapter.drop(['city1','city2','city_temp1','city_temp2','temp'], axis=1)

df_chapter['registered_db'] = 1

# %%
df_chapter.head(300)

# %%
df_chapter.shape

# %%
df_all = pd.merge(df_chapter, df_meetup, on=['city'],  how='outer')

# %%
print('emails (all):      ', chapter_list.shape)
print('emails (chapters): ', df_chapter.shape)
print('-'*30)
print('meetup dashboard:  ', df_meetup.shape)
print('-'*30)
print('Merged:            ', df_all.shape)

# %%
df_all.sort_values(by=['city'])

# %%
df_all[['email','email_signin_date','email_usage','city','country','region', 'registered_db','meetup_db','meetup_status','last_event']]

# %%
df_all = df_all.drop(['country','region'], axis=1)

# %% [markdown]
# ## 3. Data Source:  Reshama's Inventory
# ### Get raw data

# %%
file_name3 = '2021_PyLadies_Inventory - 2021-03.csv'
df_inventory = pd.read_csv(datapath+file_name3)  
df_inventory['inv_db'] = 1

# %%
#df_inventory['city'].mask(df_inventory['city'] == 'Caxias Do Sul', 'Caxias do Sul', inplace=True)
#df_inventory['city'].mask(df_inventory['city'] == 'Duque De Caxias', 'Duque de Caxias', inplace=True)
#df_inventory['city'].mask(df_inventory['city'] == 'Salt Lake Area', 'Salt Lake City', inplace=True)

# %%
df_inventory.head(5)

# %%
df_inventory.shape

# %%
df_use = pd.merge(df_all, df_inventory, on=['city'],  how='outer')

# %%
df_use = df_use.sort_values(by=['city'])

df_use.head(4)

# %%
# As a default, if meetup group exists, use that member count

#df_test=df_use.copy()

# df_test[['city', 'country','region', \
#         'registered_db','meetup_db','main_platform','meetup_members','members_followers']].head(10)
# df_test['members_followers'].mask(df_test['meetup_members'] == 'NaN', df_test['members_followers'], inplace=True)


df_use['members_followers']=df_use['meetup_members'].mask(pd.isnull, df_use['members_manual'])


df_use[['city', 'country','region', \
        'registered_db','meetup_db','main_platform','meetup_members','members_manual','members_followers']].head(100)

# %%
df_use[['city', 'country','region', \
        'registered_db','meetup_db','main_platform','meetup_members','members_followers']]

# %%
df_use.shape

# %%
#df_use[['email','email_signin_date','email_usage','city','country_x','region_x', 'country_y','region_y', 'registered_db','meetup_db','status','last_event']]
df_use[['email','email_signin_date','city', 'country','region', \
        'registered_db','meetup_db','main_platform']]

# %%
df_use['chapter_count'] = 1

# %%
df_use['meetup_db'].unique()

# %%
df_use['meetup_db'].value_counts(normalize=True)

# %%
df_use['meetup_db'].value_counts(normalize=False)

# %%
#df_use.head(3)

# %%
df_use.shape

# %% [markdown]
# ### Remove Duplicates

# %%
# get names of indexes for which 

# Note:  There are 2 registered chapters for Bengaluru
index_names = df_use[ df_use['email'] == 'bangalore@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'sa@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'mum@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'newark@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'alb@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'tampa@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

index_names = df_use[ df_use['email'] == 'tunisia@pyladies.com' ].index 
df_use.drop(index_names, inplace = True) 

# Note:  There are 2 meetup groups with same name
index_names = df_use[ df_use['meetup_url'] == 'https://www.meetup.com/Pyladies-Bogota/'].index 
df_use.drop(index_names, inplace = True) 

# Note:  There are 2 meetup groups with same name
index_names = df_use[ df_use['meetup_url'] == 'https://www.meetup.com/PyLadies-PUC-Rio/'].index 
df_use.drop(index_names, inplace = True) 


df_use.shape

# %% [markdown]
# ### Create `location` column

# %%
df_use['location'] = df_use['city'].astype(str) + ' ' + df_use['country'].astype(str)
df_use['location2']= df_use['city'].astype(str) \
                        + ' ' \
                        + df_use['state-province'].astype(str) \
                        + ' ' \
                        + df_use['country'].astype(str)


subset = df_use[['location','location2', 'city', 'state-province','country','country_level','region', 'main_platform']]
subset.head(300)

# %%
df_use.head()

# %% [markdown]
# ## For Venn Diagram

# %%
# subset = df_use[df_use["meetup"].isin(["1"])]
# subset

# %%
df_use[['email','email_signin_date','city', 'country','region', \
        'registered_db','meetup_db','main_platform']]

# %%
df_use_check=df_use[['meetup_db','registered_db','inv_db','chapter_count']]

# %%
df_check = df_use_check.groupby(['meetup_db']).sum()

# %%
df_check

# %%
df_check = df_use_check.groupby(['registered_db']).sum()

# %%
df_check

# %%
df_check = df_use_check.groupby(['inv_db']).sum()

# %%
df_check

# %%
df_check = df_use.groupby(['meetup_db','registered_db','inv_db']).sum()
#df_check = df_use.groupby(['meetup_db','registered_db','inv_db']).count()
df_check

# %%
df_use[['meetup_db','registered_db','inv_db','email','email_signin_date','city', 'state-province','country','region', 'main_platform']]

# %%
df_use.shape

# %%
# subset = df_use.query('meetup_db' in(1))
# #& registered_db == '1')


# temp = df_use[df_use.eval("meetup_db = '1'")]

# %%
df_use['status_derived'].value_counts(normalize=False)

# %%
df_use['main_platform'].value_counts(normalize=False)

# %%
subset = df_use[df_use["country_level"].isin(["1"])]
print(subset.shape)
subset.head()

# %%
df_use['region'].value_counts(normalize=False)

# %%
df_use['members_followers'].sum()

# %%
(df_use['country'].unique()).shape

# %%
df_use['country'].value_counts(normalize=False)[:10]

# %%
# 75 meetup
# 60 not found
# 135
# 261 - 135 = 125 -45 Brazil = 90

# %% [markdown]
# # Set cvs file

# %%
#df_use.sort_values(by=['region','country','city','state-province'])

df_use.sort_values(['region','country','city','state-province'], inplace=True, ascending=True)

# %%
df_use.to_csv('data_derived/pyladies_clean.csv',
              columns=['region','country','city','state-province','email','email_signin_date','email_usage', \
                       'main_platform','founded','meetup_created','main_platform_link','members_followers', \
                       'status_derived','members_manual','meetup_members', 'meetup_url', 'meetup_status','last_event',\
                       'past_events','upcoming_events','country_level','last_activity', 'facebook_page',\
                       'website','meetup_link', 'twitter_link','instagram_link','other_social_media', \
                       'meetup_db','registered_db','inv_db','meetup_name','location','location2','chapter_count'
                                 ])

# %%
#df_use.info()

# %%
df_use.head()
