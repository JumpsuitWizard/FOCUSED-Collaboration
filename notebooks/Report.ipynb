# %% [markdown]
# # FOCUSED Project: OSPO adoption
#
# As part of the [FOCUSED Collaboration project](https://github.com/JumpsuitWizard/FOCUSED-Collaboration), this notebook examines OSPO (Open Source Programs Offices) adoption across the [Standard and Poor's 500 index](https://en.wikipedia.org/wiki/S%26P_500).
#
# ## Authors
#
# - **PI**: Duane O'Brien
# - **Researcher**: julia ferraioli
# - **Analyst**: Reshama Shaikh
#
# ## Research question
#
# ## Methodology
#
# ## Data sources
#
# The following data sources are used in the analysis:
#
# - [S&P 500](https://github.com/datasets/s-and-p-500-companies/blob/master/data/constituents.csv) retrieved on 2021-10-05
# - [OSCI Index](https://opensourceindex.io/) retrieved on 2022-02-28
# - [OSPO Landscape](https://landscape.todogroup.org/) retrieved on 2022-05-09

# %% [markdown]
# ## Data setup
# ### Load the data into Pandas

# %%
import csv
import json
import numpy as np
import pandas as pd
import plotly.express as px

data_dir = "data_raw/"

# Load S&P 500 dataset into a dataframe
df_sp = pd.read_csv(data_dir+'sp500.csv')


# Load Open Source Contributor Index (OSCI) dataset into a dataframe
json_osci = json.load(open(data_dir + 'osci.json'))
df_osci = pd.read_json(data_dir + 'osci.json')
df_osci = pd.json_normalize(df_osci['data'])
print(df_osci.shape)

# Load OSPO landscape dataset into a dataframe
df_ospo = pd.read_csv(data_dir + 'ospo_todo_landscape.csv')
# Out:
# (298, 12)

# %% [markdown]
# ### Preview the data

# %%
df_sp.sample(5)
# Out:
#     Symbol                 Name                  Sector
# 77    AVGO             Broadcom  Information Technology
# 162    EMN     Eastman Chemical               Materials
# 332    NWS  News Corp (Class B)  Communication Services
# 71      BA               Boeing             Industrials
# 400    ROL              Rollins             Industrials

# %%
df_osci.sample(5)
# Out:
#      positionChange                     company  activeContributors  \
# 246             4.0                 OpenLattice                 3.0
# 39              1.0  Hewlett Packard Enterprise               148.0
# 254            -8.0                      Atypon                 3.0
# 269             6.0                   EuroLinux                 2.0
# 297             0.0                       Talan                 0.0
#
#      activeContributorsChange  totalCommunity  totalCommunityChange  position  \
# 246                       0.0               7                   0.0       247
# 39                        8.0             334                  25.0        40
# 254                       1.0               8                   1.0       255
# 269                       0.0               3                   0.0       270
# 297                       0.0               1                   0.0       298
#
#                                                    yoy  \
# 246  [{'date': '2020-04-17', 'active': 10.0}, {'dat...
# 39   [{'date': '2020-04-17', 'active': 56.0}, {'dat...
# 254  [{'date': '2020-04-17', 'active': 2.0}, {'date...
# 269  [{'date': '2020-04-17', 'active': 1.0}, {'date...
# 297  [{'date': '2020-04-17', 'active': 1.0}, {'date...
#
#                                           contributors  \
# 246  [{'Contributor': 'Matthew Tamayo-Rios', 'Commi...
# 39   [{'Contributor': 'Mitch Harding', 'Commits': 8...
# 254  [{'Contributor': 'asouqi', 'Commits': 54}, {'C...
# 269  [{'Contributor': 'Tomasz Podsiadły', 'Commits'...
# 297       [{'Contributor': 'ezzeddine', 'Commits': 3}]
#
#                                              languages  \
# 246  [{'name': 'Java', 'amount': 632}, {'name': 'CS...
# 39   [{'name': 'C#', 'amount': 3}, {'name': 'Python...
# 254  [{'name': 'Go', 'amount': 9}, {'name': 'Python...
# 269  [{'name': 'Shell', 'amount': 64}, {'name': 'C'...
# 297              [{'name': 'JavaScript', 'amount': 3}]
#
#                                               licenses               industry
# 246  [{'name': 'gpl-3.0', 'amount': 858}, {'name': ...             Technology
# 39   [{'name': 'mit', 'amount': 6425}, {'name': 'ap...             Technology
# 254  [{'name': 'apache-2.0', 'amount': 60}, {'name'...             Technology
# 269  [{'name': 'upl-1.0', 'amount': 64}, {'name': '...             Technology
# 297                     [{'name': 'mit', 'amount': 3}]  Professional Services

# %%
df_ospo.sample(5)
# Out:
#                          Name     Organization  \
# 115   Deutsche Bahn (Adopter)    Deutsche Bahn
# 8         Banco Itaú (Member)    Itau Unibanco
# 54             Nokia (Member)            Nokia
# 83   Western Digital (Member)  Western Digital
# 202                    FossID           FossID
#
#                                          Homepage  \
# 115           https://www.dbsystel.de/dbsystel-en
# 8                           https://www.itau.com/
# 54                         https://www.nokia.com/
# 83   https://github.com/westerndigitalcorporation
# 202                            https://fossid.com
#
#                                                   Logo  \
# 115  https://landscape.todogroup.org/logos/deutsche...
# 8    https://landscape.todogroup.org/logos/banco-it...
# 54   https://landscape.todogroup.org/logos/nokia-me...
# 83   https://landscape.todogroup.org/logos/western-...
# 202  https://landscape.todogroup.org/logos/foss-id.svg
#
#                                  Twitter  \
# 115          https://twitter.com/DB_Bahn
# 8    https://twitter.com/itauunibanco_ri
# 54             https://twitter.com/nokia
# 83    https://twitter.com/westerndigital
# 202        https://twitter.com/FOSSID_AB
#
#                                         Crunchbase URL    Market Cap Ticker  \
# 115  https://www.crunchbase.com/organization/deutsc...           NaN    NaN
# 8    https://www.crunchbase.com/organization/banco-...           NaN    NaN
# 54       https://www.crunchbase.com/organization/nokia           NaN    NaN
# 83   https://www.crunchbase.com/organization/wester...  2.017250e+10  WDC.F
# 202     https://www.crunchbase.com/organization/fossid           NaN    NaN
#
#          Funding   Member  ... Github Stars Github Description  \
# 115          NaN  General  ...          NaN                NaN
# 8            NaN  General  ...          NaN                NaN
# 54   868070947.0  General  ...          NaN                NaN
# 83           0.0  General  ...          NaN                NaN
# 202          NaN    false  ...          NaN                NaN
#
#     Github Latest Commit Date Github Latest Commit Link Github Release Date  \
# 115                       NaN                       NaN                 NaN
# 8                         NaN                       NaN                 NaN
# 54                        NaN                       NaN                 NaN
# 83                        NaN                       NaN                 NaN
# 202                       NaN                       NaN                 NaN
#
#     Github Release Link Github Start Commit Date Github Start Commit Link  \
# 115                 NaN                      NaN                      NaN
# 8                   NaN                      NaN                      NaN
# 54                  NaN                      NaN                      NaN
# 83                  NaN                      NaN                      NaN
# 202                 NaN                      NaN                      NaN
#
#     Github Contributors Count Github Contributors Link
# 115                       NaN                      NaN
# 8                         NaN                      NaN
# 54                        NaN                      NaN
# 83                        NaN                      NaN
# 202                       NaN                      NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Clean up the data

# %%
# Rename columns in S&P 500 and add a few fields for comparison purposes
df_sp = df_sp.rename(columns = {'Name': 'company', 'Sector': 'sector'})

df_sp['in S&P 500'] = True
df_sp['country'] = "United States"

# Reorder the columns for clarity's sake
order = ['company', 'sector', 'country', 'in S&P 500']

df_sp = df_sp.reindex(order, axis=1)

# Filter out columns from OSCI that we don't need
keep_cols = ['company', 'position', 'industry']
df_osci = df_osci.filter(keep_cols)
print(df_osci.head())

# Rename columns in OSCI and add a field for comparison purposes
df_osci = df_osci.rename(columns = {'position': 'OSCI position', 'industry': 'OSCI sector'})
df_osci['in OSCI'] = True

# Reorder the columns for clarity's sake
order = ['company', 'OSCI sector', 'OSCI position', 'in OSCI']

df_osci = df_osci.reindex(order, axis=1)

# Rename columns in OSPO Landscape and add a field for comparison purposes
df_ospo = df_ospo.rename(columns =
                         {'Name': 'OSPO status',
                          'Organization': 'company',
                          'Market Cap': 'market cap',
                          'Crunchbase Country': 'OSPO country',
                          'License': 'license'})

df_ospo['in OSPO landscape'] = True

keep_cols = ['OSPO status','company', 'market cap', 'OSPO country', 'in OSPO landscape']
df_ospo = df_ospo.filter(keep_cols)

# Filter out those who have not adopted an OSPO
df_ospo = df_ospo.loc[df_ospo['OSPO status'].str.contains("adopter", case = False)]

# Reorder the columns for clarity's sake
order = ['company', 'OSPO country', 'market cap', 'OSPO status', 'in OSPO landscape']


df_ospo = df_ospo.reindex(order, axis=1)
# Out:
#      company  position    industry
# 0     Google         1  Technology
# 1  Microsoft         2  Technology
# 2    Red Hat         3  Technology
# 3      Intel         4  Technology
# 4        IBM         5  Technology

# %% [markdown]
# ### Preview the data

# %%
df_sp.sample(5)
# Out:
#                 company                  sector        country  in S&P 500
# 340      NortonLifeLock  Information Technology  United States        True
# 240                 IBM  Information Technology  United States        True
# 245            Illumina             Health Care  United States        True
# 494  Williams Companies                  Energy  United States        True
# 460       Union Pacific             Industrials  United States        True

# %%
df_osci.sample(5)
# Out:
#           company OSCI sector  OSCI position  in OSCI
# 152     Cloudbees  Technology            153     True
# 218          eyeo  Technology            219     True
# 56   ThoughtWorks  Technology             57     True
# 256       Polidea  Technology            257     True
# 116       Spryker  Technology            117     True

# %%
df_ospo.sample(5)
# Out:
#         company   OSPO country    market cap           OSPO status  \
# 185     Wayfair  United States  9.014573e+09     Wayfair (Adopter)
# 127  Fannie Mae  United States  8.885331e+08  Fannie Mae (Adopter)
# 100   BlackRock  United States  9.675112e+10   BlackRock (Adopter)
# 137         IBM  United States  1.203220e+11         IBM (Adopter)
# 178   Two Sigma  United States           NaN   Two Sigma (Adopter)
#
#      in OSPO landscape
# 185               True
# 127               True
# 100               True
# 137               True
# 178               True

# %% [markdown]
# ### Merge the data sources

# %%
# First, merge S&P Index and OSCI, then merge with OSPO Landscape
all_data = (df_sp.merge(df_osci, left_on = 'company',
                        right_on = 'company', how = 'outer')).merge(df_ospo,
                                                                    left_on = 'company',
                                                                    right_on = 'company',
                                                                    how = 'outer')

# Prefer S&P data over OSCI and OSPO Landscape data
all_data['sector'] = all_data['sector'].mask(pd.isnull, all_data['OSCI sector'])
all_data['country'] = all_data['country'].mask(pd.isnull, all_data['OSPO country'])
all_data = all_data.drop(['OSCI sector', 'OSPO country'], axis = 1)

all_data.sort_values(by = ['company']).head(10)
# Out:
#              company                  sector        country in S&P 500  \
# 0                 3M             Industrials  United States       True
# 768        4teamwork              Technology            NaN        NaN
# 759           5minds              Technology            NaN        NaN
# 1        A. O. Smith             Industrials  United States       True
# 7                ADM        Consumer Staples  United States       True
# 11          AES Corp               Utilities  United States       True
# 526              AMD              Technology            NaN        NaN
# 44   APA Corporation                  Energy  United States       True
# 519              ARM              Technology            NaN        NaN
# 51              AT&T  Communication Services  United States       True
#
#      OSCI position in OSCI  market cap OSPO status in OSPO landscape
# 0              NaN     NaN         NaN         NaN               NaN
# 768          285.0    True         NaN         NaN               NaN
# 759          276.0    True         NaN         NaN               NaN
# 1              NaN     NaN         NaN         NaN               NaN
# 7              NaN     NaN         NaN         NaN               NaN
# 11             NaN     NaN         NaN         NaN               NaN
# 526           31.0    True         NaN         NaN               NaN
# 44             NaN     NaN         NaN         NaN               NaN
# 519           22.0    True         NaN         NaN               NaN
# 51             NaN     NaN         NaN         NaN               NaN

# %% [markdown]
# ### Do some manual cleanup for known issues

# %%
# Google is split across two Alphabet stock options and Google so we'll merge them
googles = all_data.loc[all_data['company'].str.contains('Alphabet|Google', case = False, regex = True)]
col_order = ['company', 'sector', 'country', 'in S&P 500', 'OSCI position', 'in OSCI', 'market cap',
             'OSPO status', 'in OSPO landscape']
google = googles.groupby('country', as_index = False).last()

# Update the data set and drop the extraneous entries
all_data.set_index('company', inplace = True)
all_data.update(google.set_index('company'))
all_data.reset_index(inplace = True)
all_data[all_data['company'] == 'Google']
all_data.drop(googles.iloc[:2].index, inplace= True)

# %%
all_data.sample(25)
# Out:
#                            company                  sector        country  \
# 317              Mohawk Industries  Consumer Discretionary  United States
# 136                   D. R. Horton  Consumer Discretionary  United States
# 190                       Fastenal             Industrials  United States
# 145             Diamondback Energy                  Energy  United States
# 372               Pool Corporation  Consumer Discretionary  United States
# 9               Advance Auto Parts  Consumer Discretionary  United States
# 274                KLA Corporation  Information Technology  United States
# 437              Texas Instruments  Information Technology  United States
# 355                         Paccar             Industrials  United States
# 574                  Verizon Media        Media & Telecoms  United States
# 170       Emerson Electric Company             Industrials  United States
# 157                     DTE Energy               Utilities  United States
# 187                     ExxonMobil                  Energy  United States
# 25                    Altria Group        Consumer Staples  United States
# 464             UnitedHealth Group             Health Care  United States
# 648                          Yoast              Technology            NaN
# 618                         Balena              Technology            NaN
# 745                      Infosiftr              Technology            NaN
# 131                        Coterra                  Energy  United States
# 55                        AutoZone  Consumer Discretionary  United States
# 123                 Conagra Brands        Consumer Staples  United States
# 653                       Pantheon              Technology            NaN
# 395  Regions Financial Corporation              Financials  United States
# 14        Air Products & Chemicals               Materials  United States
# 11                        AES Corp               Utilities  United States
#
#     in S&P 500  OSCI position in OSCI    market cap              OSPO status  \
# 317       True            NaN     NaN           NaN                      NaN
# 136       True            NaN     NaN           NaN                      NaN
# 190       True            NaN     NaN           NaN                      NaN
# 145       True            NaN     NaN           NaN                      NaN
# 372       True            NaN     NaN           NaN                      NaN
# 9         True            NaN     NaN           NaN                      NaN
# 274       True            NaN     NaN           NaN                      NaN
# 437       True            NaN     NaN           NaN                      NaN
# 355       True            NaN     NaN           NaN                      NaN
# 574        NaN           86.0    True  1.994409e+11  Verizon Media (Adopter)
# 170       True            NaN     NaN           NaN                      NaN
# 157       True            NaN     NaN           NaN                      NaN
# 187       True            NaN     NaN           NaN                      NaN
# 25        True            NaN     NaN           NaN                      NaN
# 464       True            NaN     NaN           NaN                      NaN
# 648        NaN          164.0    True           NaN                      NaN
# 618        NaN          134.0    True           NaN                      NaN
# 745        NaN          262.0    True           NaN                      NaN
# 131       True            NaN     NaN           NaN                      NaN
# 55        True            NaN     NaN           NaN                      NaN
# 123       True            NaN     NaN           NaN                      NaN
# 653        NaN          169.0    True           NaN                      NaN
# 395       True            NaN     NaN           NaN                      NaN
# 14        True            NaN     NaN           NaN                      NaN
# 11        True            NaN     NaN           NaN                      NaN
#
#     in OSPO landscape
# 317               NaN
# 136               NaN
# 190               NaN
# 145               NaN
# 372               NaN
# 9                 NaN
# 274               NaN
# 437               NaN
# 355               NaN
# 574              True
# 170               NaN
# 157               NaN
# 187               NaN
# 25                NaN
# 464               NaN
# 648               NaN
# 618               NaN
# 745               NaN
# 131               NaN
# 55                NaN
# 123               NaN
# 653               NaN
# 395               NaN
# 14                NaN
# 11                NaN

# %%
# Normalize the sectors across data sets

all_data['sector'].mask(all_data['sector'] == 'Information Technology', 'Technology', inplace = True)
all_data['sector'].mask(all_data['sector'] == 'Health Care', 'Healthcare & Pharma', inplace = True)
all_data['sector'].mask(all_data['sector'] == 'Financials', 'Banking, Insurance & Financial Services ', inplace = True)

# Fill null values with default ones where needed
all_data = all_data.fillna(value={'in S&P 500': False, 'in OSPO landscape': False, 'in OSCI': False,
                                  'OSCI position': 'n/a', 'OSPO status': 'n/a', 'market cap': 'unknown'})

# %% [markdown]
# ### Get a sneak peak at the data

# %%
data_sample = all_data.sample(20)
data_sample.sort_values(by = ['company'])
# Out:
#                      company                                    sector  \
# 746                  Abilian                                Technology
# 30   American Electric Power                                 Utilities
# 642                 ArangoDB                                Technology
# 715                 CS Group                                Technology
# 85     Capital One Financial  Banking, Insurance & Financial Services
# 799            Deutsche Bahn                                       NaN
# 208                      Gap                    Consumer Discretionary
# 507                   GitHub                                Technology
# 745                Infosiftr                                Technology
# 773     Insolar Technologies                                Technology
# 274          KLA Corporation                                Technology
# 278                  LabCorp                       Healthcare & Pharma
# 606                 MediaTek                                Technology
# 312     Microchip Technology                                Technology
# 543                New Relic                                Technology
# 731              OpenLattice                                Technology
# 595                 Palantir                                Technology
# 359                   Paycom                                Technology
# 401       Roper Technologies                               Industrials
# 756                     Tyro   Banking, Insurance & Financial Services
#
#            country  in S&P 500 OSCI position  in OSCI       market cap  \
# 746            NaN       False         263.0     True          unknown
# 30   United States        True           n/a    False          unknown
# 642            NaN       False         158.0     True          unknown
# 715            NaN       False         231.0     True          unknown
# 85   United States        True           n/a    False          unknown
# 799        Germany       False           n/a    False          unknown
# 208  United States        True           n/a    False          unknown
# 507  United States       False           8.0     True  2087771176960.0
# 745            NaN       False         262.0     True          unknown
# 773            NaN       False         290.0     True          unknown
# 274  United States        True           n/a    False          unknown
# 278  United States        True           n/a    False          unknown
# 606            NaN       False         122.0     True          unknown
# 312  United States        True         120.0     True          unknown
# 543  United States       False          50.0     True     3953571584.0
# 731            NaN       False         247.0     True          unknown
# 595            NaN       False         110.0     True          unknown
# 359  United States        True           n/a    False          unknown
# 401  United States        True           n/a    False          unknown
# 756            NaN       False         273.0     True          unknown
#
#                  OSPO status  in OSPO landscape
# 746                      n/a              False
# 30                       n/a              False
# 642                      n/a              False
# 715                      n/a              False
# 85                       n/a              False
# 799  Deutsche Bahn (Adopter)               True
# 208                      n/a              False
# 507         GitHub (Adopter)               True
# 745                      n/a              False
# 773                      n/a              False
# 274                      n/a              False
# 278                      n/a              False
# 606                      n/a              False
# 312                      n/a              False
# 543      New Relic (Adopter)               True
# 731                      n/a              False
# 595                      n/a              False
# 359                      n/a              False
# 401                      n/a              False
# 756                      n/a              False

# %% [markdown]
# ## Inspect the data

# %%
sp_count = len(all_data[all_data['in S&P 500']])
ospo_count = len(all_data[all_data['in OSPO landscape']])
osci_count = len(all_data[all_data['in OSCI']])
sp_ospo_count = len(all_data.query('`in S&P 500` & `in OSPO landscape`'))
sp_osci_count = len(all_data.query('`in S&P 500` & `in OSCI`'))
ospo_osci = len(all_data.query('`in OSPO landscape` & `in OSCI`'))
intersection = len(all_data.query('`in S&P 500` & `in OSPO landscape` & `in OSCI`'))

listings = pd.DataFrame([[sp_count, ospo_count, osci_count, sp_ospo_count, sp_osci_count, ospo_osci, intersection]],
                        ['count'], ['in S&P 500','in OSPO landscape','in OSCI', 'in S&P and OSPO landscape',
                        'in S&P and OSCI', 'in OSPO landscape and  OSCI', 'in all three'])
listings
# Out:
#        in S&P 500  in OSPO landscape  in OSCI  in S&P and OSPO landscape  \
# count         504                102      299                         23
#
#        in S&P and OSCI  in OSPO landscape and  OSCI  in all three
# count               23                           36            12

# %% [markdown]
# ### What companies are present in all three datasets?

# %%
all_data.query('`in S&P 500` & `in OSPO landscape` & `in OSCI`')
# Out:
#                         company                                    sector  \
# 8                         Adobe                                Technology
# 45                        Apple                                Technology
# 53                     Autodesk                                Technology
# 220               Goldman Sachs  Banking, Insurance & Financial Services
# 228  Hewlett Packard Enterprise                                Technology
# 240                         IBM                                Technology
# 248                       Intel                                Technology
# 314                   Microsoft                                Technology
# 328                     Netflix                    Communication Services
# 405                  Salesforce                                Technology
# 452                     Twitter                    Communication Services
# 505                      Google                                Technology
#
#            country  in S&P 500 OSCI position  in OSCI       market cap  \
# 8    United States        True          17.0     True   188740124672.0
# 45   United States        True          24.0     True  2608140386304.0
# 53   United States        True          98.0     True    41994772480.0
# 220  United States        True         248.0     True   107847974912.0
# 228  United States        True          40.0     True    20440801280.0
# 240  United States        True           5.0     True   120321998848.0
# 248  United States        True           4.0     True   183187193856.0
# 314  United States        True           2.0     True  2087771176960.0
# 328  United States        True          77.0     True    85567168512.0
# 405  United States        True          30.0     True   174780301312.0
# 452  United States        True          83.0     True    52861677568.0
# 505  United States        True           1.0     True  1524992311296.0
#
#                  OSPO status  in OSPO landscape
# 8            Adobe (Adopter)               True
# 45           Apple (Adopter)               True
# 53        Autodesk (Adopter)               True
# 220  Goldman Sachs (Adopter)               True
# 228            HPE (Adopter)               True
# 240            IBM (Adopter)               True
# 248          Intel (Adopter)               True
# 314      Microsoft (Adopter)               True
# 328        Netflix (Adopter)               True
# 405     Salesforce (Adopter)               True
# 452        Twitter (Adopter)               True
# 505         Google (Adopter)               True

# %% [markdown]
# ## Save processed data to file

# %%
all_data.to_csv('data_derived/merged_data.csv', index=False)
