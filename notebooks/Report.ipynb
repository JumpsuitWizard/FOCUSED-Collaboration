# %% [markdown]
# # FOCUSED Project: OSPO adoption
#
# As part of the [FOCUSED Collaboration project](https://github.com/JumpsuitWizard/FOCUSED-Collaboration), this notebook examines OSPO (Open Source Programs Offices) adoption across the [Standard and Poor's 500 index](https://en.wikipedia.org/wiki/S%26P_500).
#
# ## Authors
#
# - **PI**: Duane O'Brien
# - **Researcher**: julia ferraioli
# - **Analyst**: Reshama Shaikh
#
# ## Research question
#
# ## Methodology
#
# ## Data sources
#
# The following data sources are used in the analysis:
#
# - [S&P 500](https://github.com/datasets/s-and-p-500-companies/blob/master/data/constituents.csv) retrieved on 2021-10-05
# - [OSCI Index](https://opensourceindex.io/) retrieved on 2022-02-28
# - [OSPO Landscape](https://landscape.todogroup.org/) retrieved on 2022-05-09

# %% [markdown]
# ## Data setup
# ### Load the data into Pandas

# %%
import csv
import json
import numpy as np
import pandas as pd
import plotly.express as px

data_dir = "data_raw/"

# Load S&P 500 dataset into a dataframe
df_sp = pd.read_csv(data_dir+'sp500.csv')


# Load Open Source Contributor Index (OSCI) dataset into a dataframe
json_osci = json.load(open(data_dir + 'osci.json'))
df_osci = pd.read_json(data_dir + 'osci.json')
df_osci = pd.json_normalize(df_osci['data'])
print(df_osci.shape)

# Load OSPO landscape dataset into a dataframe
df_ospo = pd.read_csv(data_dir + 'ospo_todo_landscape.csv')
# Out:
# (298, 12)

# %% [markdown]
# ### Preview the data

# %%
df_sp.sample(5)
# Out:
#     Symbol         Name                  Sector
# 425   SNPS     Synopsys  Information Technology
# 59     BLL    Ball Corp               Materials
# 500    YUM  Yum! Brands  Consumer Discretionary
# 222    HBI  Hanesbrands  Consumer Discretionary
# 491    WRK     WestRock               Materials

# %%
df_osci.sample(5)
# Out:
#      positionChange       company  activeContributors  \
# 285             7.0          Pilz                 0.0
# 9               0.0           SAP               623.0
# 76              2.0       Netflix                70.0
# 56             -2.0  ThoughtWorks                91.0
# 203            -9.0        Tensor                10.0
#
#      activeContributorsChange  totalCommunity  totalCommunityChange  position  \
# 285                       0.0               4                   0.0       286
# 9                        51.0            1307                  83.0        10
# 76                        2.0             203                  22.0        77
# 56                       12.0             291                  25.0        57
# 203                       2.0              31                   6.0       204
#
#                                                    yoy  \
# 285  [{'date': '2020-04-17', 'active': 8.0}, {'date...
# 9    [{'date': '2020-04-17', 'active': 431.0}, {'da...
# 76   [{'date': '2020-04-17', 'active': 60.0}, {'dat...
# 56   [{'date': '2020-04-17', 'active': 182.0}, {'da...
# 203  [{'date': '2020-04-17', 'active': 56.0}, {'dat...
#
#                                           contributors  \
# 285  [{'Contributor': 'jschleicher', 'Commits': 5},...
# 9    [{'Contributor': 'Rafael Franzke', 'Commits': ...
# 76   [{'Contributor': 'Edgar Lee', 'Commits': 285},...
# 56   [{'Contributor': 'Chad Wilson', 'Commits': 151...
# 203  [{'Contributor': 'va.ten', 'Commits': 74}, {'C...
#
#                                              languages  \
# 285  [{'name': 'HTML', 'amount': 1}, {'name': 'C++'...
# 9    [{'name': 'Groovy', 'amount': 11}, {'name': 'S...
# 76   [{'name': 'Jupyter Notebook', 'amount': 65}, {...
# 56   [{'name': 'Rust', 'amount': 15}, {'name': 'Obj...
# 203  [{'name': 'Java', 'amount': 4}, {'name': 'SCSS...
#
#                                               licenses          industry
# 285  [{'name': 'bsd-3-clause', 'amount': 4}, {'name...        Technology
# 9    [{'name': 'apache-2.0', 'amount': 34358}, {'na...        Technology
# 76   [{'name': 'apache-2.0', 'amount': 2934}, {'nam...  Media & Telecoms
# 56   [{'name': 'mit', 'amount': 2253}, {'name': 'ap...        Technology
# 203  [{'name': 'mit', 'amount': 332}, {'name': 'oth...        Technology

# %%
df_ospo.sample(5)
# Out:
#                              Name   Organization  \
# 149              Netapp (Adopter)         NetApp
# 197  Debricked License Compliance      Debricked
# 45          JiHu(GitLab) (Member)         GitLab
# 66            Sauce Labs (Member)     Sauce Labs
# 109                Chef (Adopter)  Chef Software
#
#                                               Homepage  \
# 149                                 https://netapp.com
# 197  https://www.debricked.com/tools/license-compli...
# 45                             https://about.gitlab.cn
# 66                        https://github.com/saucelabs
# 109                             https://chef.github.io
#
#                                                   Logo  \
# 149  https://landscape.todogroup.org/logos/netapp-a...
# 197  https://landscape.todogroup.org/logos/debricke...
# 45   https://landscape.todogroup.org/logos/ji-hu-gi...
# 66   https://landscape.todogroup.org/logos/sauce-la...
# 109  https://landscape.todogroup.org/logos/chef-ado...
#
#                              Twitter  \
# 149       https://twitter.com/netapp
# 197  https://twitter.com/debrickedab
# 45                               NaN
# 66     https://twitter.com/saucelabs
# 109         https://twitter.com/chef
#
#                                         Crunchbase URL    Market Cap Ticker  \
# 149     https://www.crunchbase.com/organization/netapp  1.661676e+10   NTAP
# 197  https://www.crunchbase.com/organization/debricked           NaN    NaN
# 45   https://www.crunchbase.com/organization/gitlab...           NaN    NaN
# 66   https://www.crunchbase.com/organization/sauce-...           NaN    NaN
# 109       https://www.crunchbase.com/organization/chef           NaN    NaN
#
#          Funding   Member  ... Github Stars Github Description  \
# 149          0.0  General  ...          NaN                NaN
# 197    4552074.0    false  ...          NaN                NaN
# 45           0.0  General  ...          NaN                NaN
# 66   151000000.0  General  ...          NaN                NaN
# 109  105000000.0    false  ...          NaN                NaN
#
#     Github Latest Commit Date Github Latest Commit Link Github Release Date  \
# 149                       NaN                       NaN                 NaN
# 197                       NaN                       NaN                 NaN
# 45                        NaN                       NaN                 NaN
# 66                        NaN                       NaN                 NaN
# 109                       NaN                       NaN                 NaN
#
#     Github Release Link Github Start Commit Date Github Start Commit Link  \
# 149                 NaN                      NaN                      NaN
# 197                 NaN                      NaN                      NaN
# 45                  NaN                      NaN                      NaN
# 66                  NaN                      NaN                      NaN
# 109                 NaN                      NaN                      NaN
#
#     Github Contributors Count Github Contributors Link
# 149                       NaN                      NaN
# 197                       NaN                      NaN
# 45                        NaN                      NaN
# 66                        NaN                      NaN
# 109                       NaN                      NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Clean up the data

# %%
# Rename columns in S&P 500 and add a few fields for comparison purposes
df_sp = df_sp.rename(columns = {'Name': 'company', 'Sector': 'sector'})

df_sp['in S&P 500'] = True
df_sp['country'] = "United States"

# Reorder the columns for clarity's sake
order = ['company', 'sector', 'country', 'in S&P 500']

df_sp = df_sp.reindex(order, axis=1)

# Filter out columns from OSCI that we don't need
keep_cols = ['company', 'position', 'industry']
df_osci = df_osci.filter(keep_cols)
print(df_osci.head())

# Rename columns in OSCI and add a field for comparison purposes
df_osci = df_osci.rename(columns = {'position': 'OSCI position', 'industry': 'OSCI sector'})
df_osci['in OSCI'] = True

# Reorder the columns for clarity's sake
order = ['company', 'OSCI sector', 'OSCI position', 'in OSCI']

df_osci = df_osci.reindex(order, axis=1)

# Rename columns in OSPO Landscape and add a field for comparison purposes
df_ospo = df_ospo.rename(columns =
                         {'Name': 'OSPO status',
                          'Organization': 'company',
                          'Market Cap': 'market cap',
                          'Crunchbase Country': 'OSPO country',
                          'License': 'license'})

df_ospo['in OSPO landscape'] = True

keep_cols = ['OSPO status','company', 'market cap', 'OSPO country', 'in OSPO landscape']
df_ospo = df_ospo.filter(keep_cols)

# Filter out those who have not adopted an OSPO
df_ospo = df_ospo.loc[df_ospo['OSPO status'].str.contains("adopter", case = False)]

# Reorder the columns for clarity's sake
order = ['company', 'OSPO country', 'market cap', 'OSPO status', 'in OSPO landscape']


df_ospo = df_ospo.reindex(order, axis=1)
# Out:
#      company  position    industry
# 0     Google         1  Technology
# 1  Microsoft         2  Technology
# 2    Red Hat         3  Technology
# 3      Intel         4  Technology
# 4        IBM         5  Technology

# %% [markdown]
# ### Preview the data

# %%
df_sp.sample(5)
# Out:
#                            company                  sector        country  \
# 313              Micron Technology  Information Technology  United States
# 36               AmerisourceBergen             Health Care  United States
# 395  Regions Financial Corporation              Financials  United States
# 38                           Amgen             Health Care  United States
# 330                        Newmont               Materials  United States
#
#      in S&P 500
# 313        True
# 36         True
# 395        True
# 38         True
# 330        True

# %%
df_osci.sample(5)
# Out:
#        company OSCI sector  OSCI position  in OSCI
# 110     Mendix  Technology            111     True
# 106       Okta  Technology            107     True
# 95    MuleSoft  Technology             96     True
# 59   Couchbase  Technology             60     True
# 157   ArangoDB  Technology            158     True

# %%
df_ospo.sample(5)
# Out:
#          company   OSPO country    market cap            OSPO status  \
# 118      Dropbox  United States  8.088215e+09      Dropbox (Adopter)
# 104        Bosch        Germany           NaN        Bosch (Adopter)
# 172       Stripe  United States           NaN       Stripe (Adopter)
# 107  Capital One  United States  5.195379e+10  Capital One (Adopter)
# 132       Google  United States  1.524992e+12       Google (Adopter)
#
#      in OSPO landscape
# 118               True
# 104               True
# 172               True
# 107               True
# 132               True

# %% [markdown]
# ### Merge the data sources

# %%
# First, merge S&P Index and OSCI, then merge with OSPO Landscape
all_data = (df_sp.merge(df_osci, left_on = 'company',
                        right_on = 'company', how = 'outer')).merge(df_ospo,
                                                                    left_on = 'company',
                                                                    right_on = 'company',
                                                                    how = 'outer')

# Prefer S&P data over OSCI and OSPO Landscape data
all_data['sector'] = all_data['sector'].mask(pd.isnull, all_data['OSCI sector'])
all_data['country'] = all_data['country'].mask(pd.isnull, all_data['OSPO country'])
all_data = all_data.drop(['OSCI sector', 'OSPO country'], axis = 1)

all_data.sort_values(by = ['company']).head(10)
# Out:
#              company                  sector        country in S&P 500  \
# 0                 3M             Industrials  United States       True
# 768        4teamwork              Technology            NaN        NaN
# 759           5minds              Technology            NaN        NaN
# 1        A. O. Smith             Industrials  United States       True
# 7                ADM        Consumer Staples  United States       True
# 11          AES Corp               Utilities  United States       True
# 526              AMD              Technology            NaN        NaN
# 44   APA Corporation                  Energy  United States       True
# 519              ARM              Technology            NaN        NaN
# 51              AT&T  Communication Services  United States       True
#
#      OSCI position in OSCI  market cap OSPO status in OSPO landscape
# 0              NaN     NaN         NaN         NaN               NaN
# 768          285.0    True         NaN         NaN               NaN
# 759          276.0    True         NaN         NaN               NaN
# 1              NaN     NaN         NaN         NaN               NaN
# 7              NaN     NaN         NaN         NaN               NaN
# 11             NaN     NaN         NaN         NaN               NaN
# 526           31.0    True         NaN         NaN               NaN
# 44             NaN     NaN         NaN         NaN               NaN
# 519           22.0    True         NaN         NaN               NaN
# 51             NaN     NaN         NaN         NaN               NaN

# %% [markdown]
# ### Do some manual cleanup for known issues

# %%
# Google is split across two Alphabet stock options and Google so we'll merge them
googles = all_data.loc[all_data['company'].str.contains('Alphabet|Google', case = False, regex = True)]
col_order = ['company', 'sector', 'country', 'in S&P 500', 'OSCI position', 'in OSCI', 'market cap',
             'OSPO status', 'in OSPO landscape']
google = googles.groupby('country', as_index = False).last()

# Update the data set and drop the extraneous entries
all_data.set_index('company', inplace = True)
all_data.update(google.set_index('company'))
all_data.reset_index(inplace = True)
all_data[all_data['company'] == 'Google']
all_data.drop(googles.iloc[:2].index)
# Out:
#                                   company       sector        country  \
# 0                                      3M  Industrials  United States
# 1                             A. O. Smith  Industrials  United States
# 2                     Abbott Laboratories  Health Care  United States
# 3                                  AbbVie  Health Care  United States
# 4                                 Abiomed  Health Care  United States
# ..                                    ...          ...            ...
# 832  University of California, Santa Cruz          NaN  United States
# 833                               US Bank          NaN  United States
# 834                          Walmart Labs          NaN  United States
# 835                               Wayfair          NaN  United States
# 836                    Wipro Technologies          NaN          India
#
#     in S&P 500  OSCI position in OSCI    market cap  \
# 0         True            NaN     NaN           NaN
# 1         True            NaN     NaN           NaN
# 2         True            NaN     NaN           NaN
# 3         True            NaN     NaN           NaN
# 4         True            NaN     NaN           NaN
# ..         ...            ...     ...           ...
# 832        NaN            NaN     NaN           NaN
# 833        NaN            NaN     NaN  7.334153e+10
# 834        NaN            NaN     NaN  4.214506e+11
# 835        NaN            NaN     NaN  9.014573e+09
# 836        NaN            NaN     NaN  3.525762e+10
#
#                             OSPO status in OSPO landscape
# 0                                   NaN               NaN
# 1                                   NaN               NaN
# 2                                   NaN               NaN
# 3                                   NaN               NaN
# 4                                   NaN               NaN
# ..                                  ...               ...
# 832  University of Santa Cruz (Adopter)              True
# 833                   US Bank (Adopter)              True
# 834               WalmartLabs (Adopter)              True
# 835                   Wayfair (Adopter)              True
# 836                     Wipro (Adopter)              True
#
# [835 rows x 9 columns]

# %%
all_data.sample(25)
# Out:
#                          company                  sector        country  \
# 499                        Xylem             Industrials  United States
# 570                  Instructure              Technology            NaN
# 460                Union Pacific             Industrials  United States
# 132                 Crown Castle             Real Estate  United States
# 298       Marriott International  Consumer Discretionary  United States
# 392    Realty Income Corporation             Real Estate  United States
# 399          Rockwell Automation             Industrials  United States
# 136                 D. R. Horton  Consumer Discretionary  United States
# 30       American Electric Power               Utilities  United States
# 700                        Kakao        Media & Telecoms            NaN
# 398    Robert Half International             Industrials  United States
# 552                    Confluent              Technology            NaN
# 512                      Tencent        Media & Telecoms          China
# 6            Activision Blizzard  Communication Services  United States
# 365                  PerkinElmer             Health Care  United States
# 461              United Airlines             Industrials  United States
# 782                        Aiven                     NaN        Finland
# 476         Vornado Realty Trust             Real Estate  United States
# 816                         Meta                     NaN  United States
# 528                         Odoo              Technology            NaN
# 224               HCA Healthcare             Health Care  United States
# 686                      Enalean              Technology            NaN
# 453           Tyler Technologies  Information Technology  United States
# 147  Discover Financial Services              Financials  United States
# 502                Zimmer Biomet             Health Care  United States
#
#     in S&P 500  OSCI position in OSCI    market cap        OSPO status  \
# 499       True            NaN     NaN           NaN                NaN
# 570        NaN           81.0    True           NaN                NaN
# 460       True            NaN     NaN           NaN                NaN
# 132       True            NaN     NaN           NaN                NaN
# 298       True            NaN     NaN           NaN                NaN
# 392       True            NaN     NaN           NaN                NaN
# 399       True            NaN     NaN           NaN                NaN
# 136       True            NaN     NaN           NaN                NaN
# 30        True            NaN     NaN           NaN                NaN
# 700        NaN          216.0    True           NaN                NaN
# 398       True            NaN     NaN           NaN                NaN
# 552        NaN           59.0    True           NaN                NaN
# 512        NaN           14.0    True  4.506605e+11  Tencent (Adopter)
# 6         True            NaN     NaN           NaN                NaN
# 365       True            NaN     NaN           NaN                NaN
# 461       True            NaN     NaN           NaN                NaN
# 782        NaN            NaN     NaN           NaN    Aiven (Adopter)
# 476       True            NaN     NaN           NaN                NaN
# 816        NaN            NaN     NaN  5.655126e+11     Meta (Adopter)
# 528        NaN           33.0    True           NaN                NaN
# 224       True            NaN     NaN           NaN                NaN
# 686        NaN          202.0    True           NaN                NaN
# 453       True            NaN     NaN           NaN                NaN
# 147       True            NaN     NaN           NaN                NaN
# 502       True            NaN     NaN           NaN                NaN
#
#     in OSPO landscape
# 499               NaN
# 570               NaN
# 460               NaN
# 132               NaN
# 298               NaN
# 392               NaN
# 399               NaN
# 136               NaN
# 30                NaN
# 700               NaN
# 398               NaN
# 552               NaN
# 512              True
# 6                 NaN
# 365               NaN
# 461               NaN
# 782              True
# 476               NaN
# 816              True
# 528               NaN
# 224               NaN
# 686               NaN
# 453               NaN
# 147               NaN
# 502               NaN

# %%
# Normalize the sectors across data sets

all_data['sector'].mask(all_data['sector'] == 'Information Technology', 'Technology', inplace = True)
all_data['sector'].mask(all_data['sector'] == 'Health Care', 'Healthcare & Pharma', inplace = True)
all_data['sector'].mask(all_data['sector'] == 'Financials', 'Banking, Insurance & Financial Services ', inplace = True)

# Fill null values with default ones where needed
all_data = all_data.fillna(value={'in S&P 500': False, 'in OSPO landscape': False, 'in OSCI': False,
                                  'OSCI position': 'n/a', 'OSPO status': 'n/a', 'market cap': 'unknown'})

# %% [markdown]
# ### Get a sneak peak at the data

# %%
data_sample = all_data.sample(20)
data_sample.sort_values(by = ['company'])
# Out:
#                       company                                    sector  \
# 613                  Arbisoft                                Technology
# 57             Avery Dennison                                 Materials
# 571                 Bloomberg   Banking, Insurance & Financial Services
# 607                     Brave                                Technology
# 113  Citizens Financial Group  Banking, Insurance & Financial Services
# 126      Constellation Brands                          Consumer Staples
# 167      Edwards Lifesciences                       Healthcare & Pharma
# 195       First Republic Bank  Banking, Insurance & Financial Services
# 505                    Google                                Technology
# 325                      MSCI  Banking, Insurance & Financial Services
# 660     Mellanox Technologies                          Media & Telecoms
# 309                   MetLife  Banking, Insurance & Financial Services
# 563                ONLYOFFICE                                Technology
# 348      Occidental Petroleum                                    Energy
# 820                 Pinterest                                       NaN
# 377   Progressive Corporation  Banking, Insurance & Financial Services
# 758                      Pyup                                Technology
# 603                   RStudio                                Technology
# 775             SuperSoftware                                Technology
# 512                   Tencent                          Media & Telecoms
#
#            country  in S&P 500 OSCI position  in OSCI       market cap  \
# 613            NaN       False         129.0     True          unknown
# 57   United States        True           n/a    False          unknown
# 571  United States       False          82.0     True          unknown
# 607            NaN       False         123.0     True          unknown
# 113  United States        True           n/a    False          unknown
# 126  United States        True           n/a    False          unknown
# 167  United States        True           n/a    False          unknown
# 195  United States        True           n/a    False          unknown
# 505  United States        True           1.0     True  1524992311296.0
# 325  United States        True           n/a    False          unknown
# 660            NaN       False         176.0     True          unknown
# 309  United States        True           n/a    False          unknown
# 563            NaN       False          71.0     True          unknown
# 348  United States        True           n/a    False          unknown
# 820  United States       False           n/a    False    14732684288.0
# 377  United States        True           n/a    False          unknown
# 758            NaN       False         275.0     True          unknown
# 603            NaN       False         118.0     True          unknown
# 775            NaN       False         292.0     True          unknown
# 512          China       False          14.0     True   450660473370.0
#
#              OSPO status  in OSPO landscape
# 613                  n/a              False
# 57                   n/a              False
# 571  Bloomberg (Adopter)               True
# 607                  n/a              False
# 113                  n/a              False
# 126                  n/a              False
# 167                  n/a              False
# 195                  n/a              False
# 505     Google (Adopter)               True
# 325                  n/a              False
# 660                  n/a              False
# 309                  n/a              False
# 563                  n/a              False
# 348                  n/a              False
# 820  Pinterest (Adopter)               True
# 377                  n/a              False
# 758                  n/a              False
# 603                  n/a              False
# 775                  n/a              False
# 512    Tencent (Adopter)               True

# %% [markdown]
# ## Inspect the data

# %%
sp_count = len(all_data[all_data['in S&P 500']])
ospo_count = len(all_data[all_data['in OSPO landscape']])
osci_count = len(all_data[all_data['in OSCI']])
sp_ospo_count = len(all_data.query('`in S&P 500` & `in OSPO landscape`'))
sp_osci_count = len(all_data.query('`in S&P 500` & `in OSCI`'))
ospo_osci = len(all_data.query('`in OSPO landscape` & `in OSCI`'))
intersection = len(all_data.query('`in S&P 500` & `in OSPO landscape` & `in OSCI`'))

listings = pd.DataFrame([[sp_count, ospo_count, osci_count, sp_ospo_count, sp_osci_count, ospo_osci, intersection]],
                        ['count'], ['in S&P 500','in OSPO landscape','in OSCI', 'in S&P and OSPO landscape',
                        'in S&P and OSCI', 'in OSPO landscape and  OSCI', 'in all three'])
listings
# Out:
#        in S&P 500  in OSPO landscape  in OSCI  in S&P and OSPO landscape  \
# count         506                102      299                         23
#
#        in S&P and OSCI  in OSPO landscape and  OSCI  in all three
# count               23                           36            12

# %% [markdown]
# ### What companies are present in all three datasets?

# %%
all_data.query('`in S&P 500` & `in OSPO landscape` & `in OSCI`')
# Out:
#                         company                                    sector  \
# 8                         Adobe                                Technology
# 45                        Apple                                Technology
# 53                     Autodesk                                Technology
# 220               Goldman Sachs  Banking, Insurance & Financial Services
# 228  Hewlett Packard Enterprise                                Technology
# 240                         IBM                                Technology
# 248                       Intel                                Technology
# 314                   Microsoft                                Technology
# 328                     Netflix                    Communication Services
# 405                  Salesforce                                Technology
# 452                     Twitter                    Communication Services
# 505                      Google                                Technology
#
#            country  in S&P 500 OSCI position  in OSCI       market cap  \
# 8    United States        True          17.0     True   188740124672.0
# 45   United States        True          24.0     True  2608140386304.0
# 53   United States        True          98.0     True    41994772480.0
# 220  United States        True         248.0     True   107847974912.0
# 228  United States        True          40.0     True    20440801280.0
# 240  United States        True           5.0     True   120321998848.0
# 248  United States        True           4.0     True   183187193856.0
# 314  United States        True           2.0     True  2087771176960.0
# 328  United States        True          77.0     True    85567168512.0
# 405  United States        True          30.0     True   174780301312.0
# 452  United States        True          83.0     True    52861677568.0
# 505  United States        True           1.0     True  1524992311296.0
#
#                  OSPO status  in OSPO landscape
# 8            Adobe (Adopter)               True
# 45           Apple (Adopter)               True
# 53        Autodesk (Adopter)               True
# 220  Goldman Sachs (Adopter)               True
# 228            HPE (Adopter)               True
# 240            IBM (Adopter)               True
# 248          Intel (Adopter)               True
# 314      Microsoft (Adopter)               True
# 328        Netflix (Adopter)               True
# 405     Salesforce (Adopter)               True
# 452        Twitter (Adopter)               True
# 505         Google (Adopter)               True
